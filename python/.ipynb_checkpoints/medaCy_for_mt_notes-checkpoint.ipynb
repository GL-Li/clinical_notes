# %%
from medacy.model.model import Model
import pandas as pd
from tqdm import tqdm
import json

# %% [markdown]
# ## Create bag of words from medical notes

# %%
model = Model.load_external('medacy_model_clinical_notes')

# %%
# test
aaa = "PREOPERATIVE DIAGNOSIS: Abdominal wall abscess. POSTOPERATIVE DIAGNOSIS: Abdominal wall abscess. PROCEDURE: Incision and drainage (I&D) of abdominal abscess, excisional debridement of nonviable and viable skin, subcutaneous tissue and muscle, then removal of foreign body. ANESTHESIA: LMA. INDICATIONS: Patient is a pleasant 60-year-old gentleman, who initially had a sigmoid colectomy for diverticular abscess, subsequently had a dehiscence with evisceration. Came in approximately 36 hours ago with pain across his lower abdomen. CT scan demonstrated presence of an abscess beneath the incision. I recommended to the patient he undergo the above-named procedure. Procedure, purpose, risks, expected benefits, potential complications, alternatives forms of therapy were discussed with him, and he was agreeable to surgery. FINDINGS: The patient was found to have an abscess that went down to the level of the fascia. The anterior layer of the fascia was fibrinous and some portions necrotic. This was excisionally debrided using the Bovie cautery, and there were multiple pieces of suture within the wound and these were removed as well. TECHNIQUE: Patient was identified, then taken into the operating room, where after induction of appropriate anesthesia, his abdomen was prepped with Betadine solution and draped in a sterile fashion. The wound opening where it was draining was explored using a curette. The extent of the wound marked with a marking pen and using the Bovie cautery, the abscess was opened and drained. I then noted that there was a significant amount of undermining. These margins were marked with a marking pen, excised with Bovie cautery; the curette was used to remove the necrotic fascia. The wound was irrigated; cultures sent prior to irrigation and after achievement of excellent hemostasis, the wound was packed with antibiotic-soaked gauze. A dressing was applied. The finished wound size was 9. 0 x 5. 3 x 5. 2 cm in size. Patient tolerated the procedure well. Dressing was applied, and he was taken to recovery room in stable condition."
bbb = "PREOPERATIVE DIAGNOSIS: Recurrent re-infected sebaceous cyst of abdomen. POSTOPERATIVE DIAGNOSES:1. Abscess secondary to retained foreign body. 2. Incisional hernia. PROCEDURES1. Excision of abscess, removal of foreign body. 2. Repair of incisional hernia. ANESTHESIA: LMA. INDICATIONS: Patient is a pleasant 37-year-old gentleman who has had multiple procedures including a laparotomy related to trauma. The patient has had a recurrently infected cyst of his mass at the superior aspect of his incision, which he says gets larger and then it drains internally, causing him to be quite ill. He presented to my office and I recommended that he undergo exploration of this area and removal. The procedure, purpose, risks, expected benefits, potential complications, and alternative forms of therapy were discussed with him and he was agreeable to surgery. FINDINGS: The patient was found upon excision of the cyst that it contained a large Prolene suture, which is multiply knotted as it always is; beneath this was a very small incisional hernia, the hernia cavity, which contained omentum; the hernia was easily repaired. DESCRIPTION OF PROCEDURE: The patient was identified, then taken into the operating room, where after induction of an LMA anesthetic, his abdomen was prepped with Betadine solution and draped in sterile fashion. The puncta of the wound lesion was infiltrated with methylene blue and peroxide. The lesion was excised and the existing scar was excised using an ellipse and using a tenotomy scissors, the cyst was excised down to its base. In doing so, we identified a large Prolene suture within the wound and followed this cyst down to its base at which time we found that it contained omentum and was in fact overlying a small incisional hernia. The cyst was removed in its entirety, divided from the omentum using a Metzenbaum and tying with 2-0 silk ties. The hernia repair was undertaken with interrupted 0 Vicryl suture with simple sutures. The wound was then irrigated and closed with 3-0 Vicryl subcutaneous and 4-0 Vicryl subcuticular and Steri-Strips. Patient tolerated the procedure well. Dressings were applied and he was taken to recovery room in stable condition."
annotation = model.predict(bbb)
#get_bows([aaa])

# %%
list(annotation)
# Out:
# [('Drug', 1405, 1413, 'peroxide'),
#  ('Drug', 2016, 2022, 'Vicryl'),
#  ('Route', 2023, 2035, 'subcutaneous')]

# %%
dat = pd.read_csv("mtsample_gastroenterology_neurology.csv")
notes = list(dat.medical_note)
# Out:
# ['PREOPERATIVE DIAGNOSIS: Abdominal wall abscess.POSTOPERATIVE DIAGNOSIS: Abdominal wall abscess.PROCEDURE: Incision and drainage (I&D) of abdominal abscess, excisional debridement of nonviable and viable skin, subcutaneous tissue and muscle, then removal of foreign body.ANESTHESIA: LMA.INDICATIONS: Patient is a pleasant 60-year-old gentleman, who initially had a sigmoid colectomy for diverticular abscess, subsequently had a dehiscence with evisceration. Came in approximately 36 hours ago with pain across his lower abdomen. CT scan demonstrated presence of an abscess beneath the incision. I recommended to the patient he undergo the above-named procedure. Procedure, purpose, risks, expected benefits, potential complications, alternatives forms of therapy were discussed with him, and he was agreeable to surgery.FINDINGS: The patient was found to have an abscess that went down to the level of the fascia. The anterior layer of the fascia was fibrinous and some portions necrotic. This was excisionally debrided using the Bovie cautery, and there were multiple pieces of suture within the wound and these were removed as well.TECHNIQUE: Patient was identified, then taken into the operating room, where after induction of appropriate anesthesia, his abdomen was prepped with Betadine solution and draped in a sterile fashion. The wound opening where it was draining was explored using a curette. The extent of the wound marked with a marking pen and using the Bovie cautery, the abscess was opened and drained. I then noted that there was a significant amount of undermining. These margins were marked with a marking pen, excised with Bovie cautery; the curette was used to remove the necrotic fascia. The wound was irrigated; cultures sent prior to irrigation and after achievement of excellent hemostasis, the wound was packed with antibiotic-soaked gauze. A dressing was applied. The finished wound size was 9.0 x 5.3 x 5.2 cm in size. Patient tolerated the procedure well. Dressing was applied, and he was taken to recovery room in stable condition.',
#  "PREOPERATIVE DIAGNOSES: 1. Congenital chylous ascites and chylothorax.2. Rule out infradiaphragmatic lymphatic leak.POSTOPERATIVE DIAGNOSES: Diffuse intestinal and mesenteric lymphangiectasia.ANESTHESIA: General.INDICATION: The patient is an unfortunate 6-month-old baby boy, who has been hospitalized most of his life with recurrent chylothoraces and chylous ascites. The patient has been treated somewhat successfully with TPN and voluntary restriction of enteral nutrition, but he had repeated chylothoraces. Last week, Dr. X took the patient to the operating room in hopes that with thoracotomy, a thoracic duct leak could be found, which would be successfully closed surgically. However at the time of his thoracotomy exploration what was discovered was a large amount of transdiaphragmatic transition of chylous ascites coming from the abdomen. Dr. X opened the diaphragm and could literally see a fountain of chylous fluid exiting through the diaphragmatic hole. This was closed, and we decided that perhaps an abdominal exploration as a last stage effort would allow us to find an area of lymphatic leak that could potentially help the patient from this dismal prognostic disease. We met with his parents and talked to them about this, and he is here today for that attempt.OPERATIVE FINDINGS: The patient's abdomen was relatively soft, minimally distended. Exploration through supraumbilical transverse incision immediately revealed a large amount of chylous ascites upon entering into the peritoneal cavity. What we found which explains the chronic chylous ascites and chylothorax was a diffuse lymphangiectatic picture involving the small bowel mesentery approximately two thirds to three quarters of the distal small bowel including all of the ileum, the cecum, and the portion of the ascending colon. It appeared that any attempt to resect this area would have been met with failure because of the extensive lymphatic dilatation all the way down towards the root of the supramesenteric artery. There was about one quarter to one third of the jejunum that did not appear to be grossly involved, but I did not think that resection of three quarters of the patient's small bowel would be viable surgical option. Instead, we opted to close his abdomen and refer for potential small intestine transplantation procedure in the future if he is a candidate for that.The lymphatic abnormality was extensive. They were linear dilated lymphatic channels on the serosal surface of the bowel in the mesentery. They were small aneurysm-like pockets of chyle all along the course of the mesenteric structures and in the mesentery medially adjacent to the bowel as well. No other major retroperitoneal structure or correctable structure was identified. Both indirect inguinal hernias were wide open and could be palpated from an internal aspect as well.DESCRIPTION OF OPERATION: The patient was brought from the Pediatric Intensive Care Unit to the operating room within an endotracheal tube im place and with enteral feeds established at full flow to provide maximum fat content and maximum lymphatic flow. We conducted a surgical time-out and reiterated all of the patient's important identifying information and confirmed the operative plan as described above. Preparation and draping of his abdomen was done with chlorhexidine based prep solution and then we opened his peritoneal cavity through a transverse supraumbilical incision dividing both rectus muscles and all layers of the abdominal wall fascia. As the peritoneal cavity was entered, we divided the umbilical vein ligamentum teres remnant between Vicryl ties, and we were able to readily identify a large amount of chylous ascites that had been previously described. The bowel was eviscerated, and then with careful inspection, we were able to identify this extensive area of intestinal and mesenteric lymphangiectasia that was a source of the patient's chylous ascites. The small bowel from the ligament of Treitz to the proximal to mi ...
#  'CHIEF COMPLAINT: Abdominal pain.HISTORY OF PRESENT ILLNESS: The patient is a 71-year-old female patient of Dr. X. The patient presented to the emergency room last evening with approximately 7- to 8-day history of abdominal pain which has been persistent. She was seen 3 to 4 days ago at ABC ER and underwent evaluation and discharged and had a CT scan at that time and she was told it was "normal." She was given oral antibiotics of Cipro and Flagyl. She has had no nausea and vomiting, but has had persistent associated anorexia. She is passing flatus, but had some obstipation symptoms with the last bowel movement two days ago. She denies any bright red blood per rectum and no history of recent melena. Her last colonoscopy was approximately 5 years ago with Dr. Y. She has had no definite fevers or chills and no history of jaundice. The patient denies any significant recent weight loss.PAST MEDICAL HISTORY: Significant for history of atrial fibrillation, under good control and now in normal sinus rhythm and on metoprolol and also on Premarin hormone replacement.PAST SURGICAL HISTORY: Significant for cholecystectomy, appendectomy, and hysterectomy. She has a long history of known grade 4 bladder prolapse and she has been seen in the past by Dr. Chip Winkel, I believe that he has not been re-consulted.ALLERGIES: SHE IS ALLERGIC OR SENSITIVE TO MACRODANTIN.SOCIAL HISTORY: She does not drink or smoke.REVIEW OF SYSTEMS: Otherwise negative for any recent febrile illnesses, chest pains or shortness of breath.PHYSICAL EXAMINATION:GENERAL: The patient is an elderly thin white female, very pleasant, in no acute distress.VITAL SIGNS: Her temperature is 98.8 and vital signs are all stable, within normal limits.HEENT: Head is grossly atraumatic and normocephalic. Sclerae are anicteric. The conjunctivae are non-injected.NECK: Supple.CHEST: Clear.HEART: Regular rate and rhythm.ABDOMEN: Generally nondistended and soft. She is focally tender in the left lower quadrant to deep palpation with a palpable fullness or mass and focally tender, but no rebound tenderness. There is no CVA or flank tenderness, although some very minimal left flank tenderness.PELVIC: Currently deferred, but has history of grade 4 urinary bladder prolapse.EXTREMITIES: Grossly and neurovascularly intact.LABORATORY VALUES: White blood cell count is 5.3, hemoglobin 12.8, and platelet count normal. Alkaline phosphatase elevated at 184. Liver function tests otherwise normal. Electrolytes normal. Glucose 134, BUN 4, and creatinine 0.7.DIAGNOSTIC STUDIES: EKG shows normal sinus rhythm.IMPRESSION AND PLAN: A 71-year-old female with greater than one-week history of abdominal pain now more localized to the left lower quadrant. Currently is a nonacute abdomen. The working diagnosis would be sigmoid diverticulitis. She does have a history in the distant past of sigmoid diverticulitis. I would recommend a repeat stat CT scan of the abdomen and pelvis and keep the patient nothing by mouth. The patient was seen 5 years ago by Dr. Y in Colorectal Surgery. We will consult her also for evaluation. The patient will need repeat colonoscopy in the near future and be kept nothing by mouth now empirically. The case was discussed with the patient\'s primary care physician, Dr. X. Again, currently there is no indication for acute surgical intervention on today\'s date, although the patient will need close observation and further diagnostic workup.',
#  'PREOPERATIVE DIAGNOSIS: Recurrent re-infected sebaceous cyst of abdomen.POSTOPERATIVE DIAGNOSES:1. Abscess secondary to retained foreign body.2. Incisional hernia.PROCEDURES1. Excision of abscess, removal of foreign body.2. Repair of incisional hernia.ANESTHESIA: LMA.INDICATIONS: Patient is a pleasant 37-year-old gentleman who has had multiple procedures including a laparotomy related to trauma. The patient has had a recurrently infected cyst of his mass at the superior aspect of his incision, which he says gets larger and then it drains internally, causing him to be quite ill. He presented to my office and I recommended that he undergo exploration of this area and removal. The procedure, purpose, risks, expected benefits, potential complications, and alternative forms of therapy were discussed with him and he was agreeable to surgery.FINDINGS: The patient was found upon excision of the cyst that it contained a large Prolene suture, which is multiply knotted as it always is; beneath this was a very small incisional hernia, the hernia cavity, which contained omentum; the hernia was easily repaired.DESCRIPTION OF PROCEDURE: The patient was identified, then taken into the operating room, where after induction of an LMA anesthetic, his abdomen was prepped with Betadine solution and draped in sterile fashion. The puncta of the wound lesion was infiltrated with methylene blue and peroxide. The lesion was excised and the existing scar was excised using an ellipse and using a tenotomy scissors, the cyst was excised down to its base. In doing so, we identified a large Prolene suture within the wound and followed this cyst down to its base at which time we found that it contained omentum and was in fact overlying a small incisional hernia. The cyst was removed in its entirety, divided from the omentum using a Metzenbaum and tying with 2-0 silk ties. The hernia repair was undertaken with interrupted 0 Vicryl suture with simple sutures. The wound was then irrigated and closed with 3-0 Vicryl subcutaneous and 4-0 Vicryl subcuticular and Steri-Strips. Patient tolerated the procedure well. Dressings were applied and he was taken to recovery room in stable condition.',
#  'CHIEF COMPLAINT: Nausea.PRESENT ILLNESS: The patient is a 28-year-old, who is status post gastric bypass surgery nearly one year ago. He has lost about 200 pounds and was otherwise doing well until yesterday evening around 7:00-8:00 when he developed nausea and right upper quadrant pain, which apparently wrapped around toward his right side and back. He feels like he was on it but has not done so. He has overall malaise and a low-grade temperature of 100.3. He denies any prior similar or lesser symptoms. His last normal bowel movement was yesterday. He denies any outright chills or blood per rectum.PAST MEDICAL HISTORY: Significant for hypertension and morbid obesity, now resolved.PAST SURGICAL HISTORY: Gastric bypass surgery in December 2007.MEDICATIONS: Multivitamins and calcium.ALLERGIES: None known.FAMILY HISTORY: Positive for diabetes mellitus in his father, who is now deceased.SOCIAL HISTORY: He denies tobacco or alcohol. He has what sounds like a data entry computer job.REVIEW OF SYSTEMS: Otherwise negative.PHYSICAL EXAMINATION: His temperature is 100.3, blood pressure 129/59, respirations 16, heart rate 84. He is drowsy, but easily arousable and appropriate with conversation. He is oriented to person, place, and situation. He is normocephalic, atraumatic. His sclerae are anicteric. His mucous membranes are somewhat tacky. His neck is supple and symmetric. His respirations are unlabored and clear. He has a regular rate and rhythm. His abdomen is soft. He has diffuse right upper quadrant tenderness, worse focally, but no rebound or guarding. He otherwise has no organomegaly, masses, or abdominal hernias evident. His extremities are symmetrical with no edema. His posterior tibial pulses are palpable and symmetric. He is grossly nonfocal neurologically.STUDIES: His white blood cell count is 8.4 with 79 segs. His hematocrit is 41. His electrolytes are normal. His bilirubin is 2.8. His AST 349, ALT 186, alk-phos 138 and lipase is normal at 239.ASSESSMENT: Choledocholithiasis, ? cholecystitis.PLAN: He will be admitted and placed on IV antibiotics. We will get an ultrasound this morning. He will need his gallbladder out, probably with intraoperative cholangiogram. Hopefully, the stone will pass this way. Due to his anatomy, an ERCP would prove quite difficult if not impossible unless laparoscopic assisted. Dr. X will see him later this morning and discuss the plan further. The patient understands.',
#  'PREOPERATIVE DIAGNOSES1. Adrenal mass, right sided.2. Umbilical hernia.POSTOPERATIVE DIAGNOSES1. Adrenal mass, right sided.2. Umbilical hernia.OPERATION PERFORMED: Laparoscopic hand-assisted left adrenalectomy and umbilical hernia repair.ANESTHESIA: General.CLINICAL NOTE: This is a 52-year-old inmate with a 5.5 cm diameter nonfunctioning mass in his right adrenal. Procedure was explained including risks of infection, bleeding, possibility of transfusion, possibility of further treatments being required. Alternative of fully laparoscopic are open surgery or watching the lesion.DESCRIPTION OF OPERATION: In the right flank-up position, table was flexed. He had a Foley catheter in place. Incision was made from just above the umbilicus, about 5.5 cm in diameter. The umbilical hernia was taken down. An 11 mm trocar was placed in the midline, superior to the GelPort and a 5 mm trocar placed in the midaxillary line below the costal margin. A liver retractor was placed to this.The colon was reflected medially by incising the white line of Toldt. The liver attachments to the adrenal kidney were divided and the liver was reflected superiorly. The vena cava was identified. The main renal vein was identified. Coming superior to the main renal vein, staying right on the vena cava, all small vessels were clipped and then divided. Coming along the superior pole of the kidney, the tumor was dissected free from top of the kidney with clips and Bovie. The harmonic scalpel was utilized superiorly and laterally. Posterior attachments were divided between clips and once the whole adrenal was mobilized, the adrenal vein and one large adrenal artery were noted, doubly clipped, and divided. Specimen was placed in a collection bag, removed intact.Hemostasis was excellent.The umbilical hernia had been completely taken down. The edges were freshened up. Vicryl #1 was utilized to close the incision and 2-0 Vicryl was used to close the fascia of the trocar.Skin closed with clips.He tolerated the procedure well. All sponge and instrument counts were correct. Estimated blood loss less than 100 mL.The patient was awakened, extubated, and returned to recovery room in satisfactory condition.',
#  "REASON FOR CONSULTATION: Possible free air under the diaphragm.HISTORY OF PRESENT ILLNESS: The patient is a 77-year-old female who is unable to give any information. She has been sedated with Ativan and came into the emergency room obtunded and unable to give any history. On a chest x-ray for what appeared to be shortness of breath she was found to have what was thought to be free air under the right diaphragm.PAST MEDICAL HISTORY: Significant for alcohol abuse. Unable to really gather any other information because she is so obtunded.PAST SURGICAL HISTORY: Looking at the medical chart, she had an appendectomy, right hip fracture from a fall in 2005, and TAH/BSO.MEDICATIONS: Unable to evaluate.ALLERGIES: UNABLE TO EVALUATE.SOCIAL HISTORY: Significant history of alcohol abuse, according to the emergency room physician, who sees her on a regular basis.REVIEW OF SYSTEMS: Unable to obtain.PHYSICAL EXAMVITAL SIGNS: Temp 98.3, heart rate 82, respiratory rate 24, and blood pressure 141/70.GENERAL: She is a very obtunded female who upon arousal is not able to provide any information of any use.HEENT: Atraumatic.NECK: Soft and supple.LUNGS: Bilaterally diminished.HEART: Regular.ABDOMEN: Soft, and with deep palpation I am unable to arouse the patient, unable to elicit any tenderness.LABORATORY STUDIES: Show a normal white blood cell count with no shift. Elevated AST at 138, with a normal ALT at 38. Alkaline phosphatase of 96, bilirubin 0.8. Sodium is 107, with 68 chloride and potassium of 2.8.X-ray of the chest shows the possibility of free air; therefore, a CT scan was obtained because of the patient's physical examination, which shows no evidence of intra-abdominal pathology. The etiology of the air under the diaphragm is actually a colonic air that is anterior superior to the dome of the diaphragm, near the dome of the liver.ASSESSMENT: No intra-abdominal pathology.PLAN: Have her admitted to the medical service for treatment of her hyponatremia.",
#  'PREOPERATIVE DIAGNOSIS: Appendicitis.POSTOPERATIVE DIAGNOSIS: Appendicitis, nonperforated.PROCEDURE PERFORMED: Appendectomy.ANESTHESIA: General endotracheal.PROCEDURE: After informed consent was obtained, the patient was brought to the operative suite and placed supine on the operating table. General endotracheal anesthesia was induced without incident. The patient was prepped and draped in the usual sterile manner.A transverse right lower quadrant incision was made directly over the point of maximal tenderness. Sharp dissection utilizing Bovie electrocautery was used to expose the external oblique fascia. The fascia of the external oblique was incised in the direction of the fibers, and the muscle was spread with a clamp. The internal oblique fascia was similarly incised and its muscular fibers were similarly spread. The transversus abdominis muscle, transversalis fascia and peritoneum were incised sharply gaining entrance into the abdominal cavity without incident. Upon entering the peritoneal cavity, the peritoneal fluid was noted to be clean.The cecum was then grasped along the taenia with a moist gauze sponge and was gently mobilized into the wound. After the appendix was fully visualized, the mesentery was divided between Kelly clamps and ligated with 2-0 Vicryl ties. The base of the appendix was crushed with a clamp and then the clamp was reapplied proximally on the appendix. The base was ligated with 2-0 Vicryl tie over the crushed area, and the appendix amputated along the clamp. The stump of the appendix was cauterized and the cecum was returned to the abdomen.The peritoneum was irrigated with warm sterile saline. The mesoappendix and cecum were examined for hemostasis which was present. The wound was closed in layers using 2-0 Vicryl for the peritoneum and 0 Vicryl for the internal oblique and external oblique layers. The skin incision was approximated with 4-0 Monocryl in a subcuticular fashion. The skin was prepped with benzoin, and Steri-Strips were applied. A dressing was placed on the wound. All surgical counts were reported as correct.Having tolerated the procedure well, the patient was subsequently extubated and taken to the recovery room in good and stable condition.',
#  'PREOPERATIVE DIAGNOSIS: Acute appendicitis.POSTOPERATIVE DIAGNOSIS: Acute appendicitis, gangrenous.PROCEDURE: Appendectomy.DESCRIPTION OF PROCEDURE: The patient was taken to the operating room under urgent conditions. After having obtained an informed consent, he was placed in the operating room and under anesthesia. Followed by a time-out process, his abdominal wall was prepped and draped in the usual fashion. Antibiotics had been given prior to incision. A McBurney incision was performed and it carried out through the peritoneal cavity. Immediately there was purulent material seen in the area. Samples were taken for culture and sensitivity of aerobic and anaerobic sets. The appendix was markedly swollen particularly in its distal three-fourth, where the distal appendix showed an abscess formation and devitalization of the wall. There was quite a bit of local peritonitis. The mesoappendix was clamped, divided and ligated, and then the appendix was ligated and divided, and the stump buried with a pursestring suture of Vicryl and then a Z stitch. The area was abundantly irrigated with normal saline and also the pelvis. The distal foot of small bowel had been explored and because it delivered itself __________ the incision and showed no pathology.Then the peritoneal and internal fascia were approximated with a suture of 0 Vicryl and then the incision was closed in layers and after each layer the wound was irrigated with normal saline. The skin was closed with a combination of a subcuticular suture of fine Monocryl followed by the application of Dermabond. The patient tolerated the procedure well. Estimated blood loss was minimal, and the patient was sent to the recovery room for recovery in satisfactory condition.',
#  "PREOPERATIVE DIAGNOSIS: Acute appendicitis.POSTOPERATIVE DIAGNOSES:1. Pelvic inflammatory disease.2. Periappendicitis.PROCEDURE PERFORMED:1. Laparoscopic appendectomy.2. Peritoneal toilet and photos.ANESTHESIA: General.COMPLICATIONS: None.ESTIMATED BLOOD LOSS: Less than 10 cc.INDICATIONS FOR PROCEDURE: The patient is a 31-year-old African-American female who presented with right lower quadrant abdominal pain presented with acute appendicitis. She also had mild leukocytosis with bright blood cell count of 12,000. The necessity for diagnostic laparoscopy was explained and possible appendectomy. The patient is agreeable to proceed and signed preoperatively informed consent.PROCEDURE: The patient was taken to the operative suite and placed in the supine position under general anesthesia by Anesthesia Department.The preoperative Foley, antibiotics, and NG tube are placed for decompression and the anterior abdominal wall was prepped and draped in the usual sterile fashion and infraumbilical incision is performed with a #10 blade scalpel with anterior and superior traction on the abdominal wall. A Veress needle was introduced and 15 mm pneumoperitoneum is created with CO2 insufflation. At this point, the Veress needle was removed and a 10 mm trocar is introduced intraperitoneally. A second 5 mm port was introduced in the right upper quadrant under direct visualization and blunted graspers were introduced to bring the appendix into view. With the aid of a laparoscope, the pelvis was visualized. The ovaries are brought in views and photos are taken. There is evidence of a purulence in the cul-de-sac and ________ with a right ovarian hemorrhagic cyst. Attention was then turned on the right lower quadrant. The retrocecal appendix is freed with peritoneal adhesions removed with Endoshears. Attention was turned to the suprapubic area. The 12 mm port was introduced under direct visualization and the mesoappendix was identified. A 45 mm endovascular stapling device was fired across the mesoappendix and the base of the appendix sequentially with no evidence of bleeding or leakage from the staple line. Next, ________ tube was used to obtain Gram stain and cultures of the pelvic fluid and a pelvic toilet was performed with copious irrigation of sterile saline. Next, attention was turned to the right upper quadrant. There is evidence of adhesions from the liver surface to the anterior abdominal wall consistent with Fitz-Hugh-Curtis syndrome also a prior pelvic inflammatory disease. All free fluid is aspirated and patient's all port sites are removed under direct visualization and the appendix is submitted to pathology for final pathology. Once the ports are removed the pneumoperitoneum is allowed to escape for patient's postoperative comfort and two larger port sites at the suprapubic and infraumbilical sites are closed with #0 Vicryl suture on a UR-6 needle. Local anesthetic is infiltrated at L3 port sites for postoperative analgesia and #4-0 Vicryl subcuticular closure is performed with undyed Vicryl. Steri-Strips are applied along with sterile dressings. The patient was awakened from anesthesia without difficulty and transferred to recovery room with postoperative broad-spectrum IV antibiotics in the General Medical Floor. Routine postoperative care will be continued on this patient."]

# %%
# an annotation looks like:
# [('Drug', 1405, 1413, 'peroxide'),
# ('Drug', 2016, 2022, 'Vicryl'),
# ('Route', 2023, 2035, 'subcutaneous')]
# So the element of index 3 is the keyword
def get_bows(notes):
    # notes: medical notes as a list of strings
    bows = []
    for note in tqdm(notes):
        annotation = model.predict(note)
        bow = [ann[3].replace(" ", "-") for ann in list(annotation)]
        bow = " ".join(bow)
        bows.append(bow)
    return(bows)

# %%
bows = get_bows(notes)
# Out:
# 100%|██████████| 451/451 [01:06<00:00,  6.75it/s]

# %%
# save bows which take 13 min to run
with open("bows_medacy_gas_neu.txt", "w") as f:
    json.dump(bows, f)
    
with open("bows_medacy_gas_neu.txt", "r") as f:
    if "bows" not in globals():
        bows = json.load(f)

# %%
bows_gas_neu_df = pd.DataFrame({
    "id" : range(1, 452),
    "medacy_me" : bows
})
bows_gas_neu_df.to_csv("medacy_medical_entities.csv", index=False)

# %%
bows
# Out:
# [['foreign-body'],
#  ['lymphatic-leak',
#   'chlorhexidine',
#   'Subcuticular-5-0',
#   'Monocryl',
#   'skin-closure',
#   '100-mL'],
#  ['oral',
#   'antibiotics',
#   'Cipro',
#   'Flagyl',
#   'atrial-fibrillation',
#   'metoprolol',
#   'Premarin-hormone',
#   'replacement.',
#   'creatinine',
#   '0.'],
#  ['peroxide', 'Vicryl', 'subcutaneous'],
#  ['right-upper-quadrant-pain', 'calcium', 'antibiotics'],
#  ['Vicryl', 'Vicryl'],
#  ['Ativan', 'hyponatremia'],
#  ['Vicryl', 'saline', 'Vicryl', 'Vicryl', 'benzoin'],
#  ['Acute-appendicitis',
#   'Acute-appendicitis',
#   'anesthesia',
#   'local-peritonitis',
#   'Vicryl',
#   'Z-stitch',
#   'Vicryl',
#   'normal-saline',
#   'fine-Monocryl'],
#  ['Acute-appendicitis',
#   'anesthesia',
#   'antibiotics',
#   'saline',
#   'right-upper-quadrant',
#   'Vicryl',
#   'Vicryl',
#   'antibiotics'],
#  ['Acute-appendicitis',
#   'Acute-appendicitis',
#   'acute-appendicitis',
#   'saline-antibiotic'],
#  ['Acute-appendicitis',
#   'Acute-suppurative-appendicitis',
#   'Marcaine',
#   'acute-appendicitis',
#   'acute-appendicitis',
#   'Marcaine',
#   '0.25',
#   'antibiotics'],
#  ['Barium-enema', 'constipation', 'barium-contrast'],
#  ['chemotherapy',
#   'April',
#   'decreased-leakage-from-his-trach',
#   'Passy',
#   'chemotherapy',
#   'increase-laryngeal-movement'],
#  ['TIA/stroke', 'bolus'],
#  ['bolus', 'bolus'],
#  ['bolus', 'decrease-bacterial-growth'],
#  ['Demerol', '25', 'proton-pump-inhibitors', 'antiemetics'],
#  [],
#  ['lower-gastrointestinal-bleeding',
#   'pneumonia',
#   'lower-gastrointestinal-bleeding',
#   'Diltiazem',
#   '30-mg',
#   'tid',
#   'pantoprazole',
#   '40-mg',
#   'qd',
#   'epoetin-alfa',
#   '40,',
#   '000-units',
#   'weekly',
#   'iron',
#   '325-mg',
#   'bid',
#   'cholestyramine',
#   'Warfarin',
#   '1',
#   'liter-normal-saline',
#   'diltiazem',
#   '20-mg',
#   'intravenously',
#   '30-mg',
#   '50',
#   'topical',
#   'benzocaine',
#   '20',
#   'methylene-blue',
#   'oxygen'],
#  ['diffuse-colitis',
#   'Flagyl',
#   'Levaquin',
#   'Reglan',
#   'atenolol',
#   'Mevacor',
#   'Diarrhea',
#   'Reglan',
#   'oxygen',
#   'leukocytosis',
#   'Levaquin',
#   'p.o.',
#   'vancomycin',
#   'oxygen'],
#  ['anesthesia', 'dye', 'antibiotic', 'Mastisol'],
#  ['Diovan',
#   '5-mg',
#   'daily',
#   'Lipitor',
#   '10-mg',
#   'daily',
#   'Lutein',
#   '20-mg',
#   'daily',
#   'folic-acid',
#   '0.8-mg',
#   'daily',
#   'multivitamin',
#   'daily',
#   'HEART-RATE',
#   'carcinoma'],
#  ['One-1',
#   'general-endotracheal-anesthesia',
#   'Vicryl',
#   'Vicryl',
#   'Vicryl',
#   'anesthesia'],
#  ['right-upper-quadrant-pain', 'local-anesthesia', 'Vicryl'],
#  ['Marcaine',
#   'antibiotics',
#   'subcutaneous',
#   'heparin',
#   'saline',
#   'local',
#   'injectable-0.25',
#   'Marcaine'],
#  ['laparoscopic-cholecystectomy',
#   'pain-control-with-oral-pain',
#   'iron',
#   '325-mg',
#   'p.o.',
#   't.i.d.',
#   '15-cc',
#   'p.o.',
#   'q.4-h.-p.r.n.',
#   'pain'],
#  ['Xylocaine', '1%', 'Epinephrine', 'Xylocaine'],
#  ['mL',
#   'Clostridium-difficile',
#   'Clostridium-difficile-colitis',
#   'Acute-renal-failure',
#   'Clostridium-difficile-colitis',
#   'Flagyl',
#   'Levaquin',
#   'pneumonia',
#   'vancomycin'],
#  ['PENICILLIN',
#   'two-glasses',
#   'white-wine',
#   '3-L',
#   'nasal-cannula',
#   'creatinine',
#   '0.7',
#   'borderline',
#   'chemotherapy',
#   'chemotherapy',
#   'Chemotherapy'],
#  ['conscious-sedation'],
#  ['Include-Serevent',
#   'two',
#   'puffs',
#   'daily',
#   'Nasonex',
#   'two',
#   'sprays',
#   'daily',
#   'penicillin',
#   'anxiety',
#   'HEART-RATE'],
#  ['anemia'],
#  ['constipation', 'fiber', 'two', 'tablets', 'twice-a-day'],
#  [],
#  ['Demerol', 'intravenously'],
#  ['Vistaril',
#   '50-mg',
#   'Atropine',
#   '0.4-mg',
#   'IM',
#   'intravenous',
#   'Demerol',
#   '50-mg',
#   'Versed',
#   '5-mg'],
#  ['100-mg', 'Demerol', ',-3-mg', 'Versed'],
#  ['50-mg', 'Demerol', '3.75-mg', 'Versed'],
#  [],
#  [],
#  ['Demerol',
#   '100-mg',
#   'Versed',
#   '3-mg',
#   'Demerol',
#   '100-mg',
#   'Versed',
#   '3-mg'],
#  ['sedation'],
#  ['Fentanyl', '100-mcg', 'versed', '10-mg'],
#  ['Versed', '5-mg', 'Demerol', '50'],
#  ['Versed', '3-mg', 'Demerol', '25-mg'],
#  ['Fentanyl',
#   '75-mcg',
#   'Versed',
#   '6-mg',
#   'glucagon-1.5-units',
#   'push-in-divided',
#   'epinephrine',
#   'epinephrine',
#   'epinephrine',
#   'epinephrine',
#   'epinephrine',
#   'glucagon'],
#  ['circumferential-manner'],
#  ['sever-headache',
#   '5-mg',
#   'Demerol',
#   'Demerol',
#   'nausea-reaction',
#   '25-mg',
#   'Phenergan',
#   '7.5-mg'],
#  ['Versed', '5-mg', 'Demerol', '7'],
#  ['Midazolam',
#   '2-mg',
#   'Fentanyl',
#   '100-mcg',
#   'sedation',
#   'saline',
#   'injection'],
#  ['Fentanyl', '100-mcg', '3-mg', 'Versed'],
#  ['Fentanyl', '150-mcg', 'Versed', '7-mg'],
#  ['sulfasalazine',
#   'cortisone',
#   'oxygen',
#   'steroid',
#   'taper',
#   'steroid',
#   'taper',
#   'immune-suppressive-medication',
#   'azathioprine'],
#  ['Versed', '5-mg', 'Demerol', '100'],
#  ['Nexium', 'Demerol', 'Versed', 'Cetacaine-spray', 'Nexium'],
#  ['Versed', '8-mg', '175-mcg', 'fentanyl'],
#  ['175-mcg', 'fentanyl', 'conscious-sedation'],
#  ['Fentanyl', '100'],
#  [],
#  [],
#  ['sedation'],
#  [],
#  ['fentanyl'],
#  ['heme-positive-stools', '4-mg', '75-mg', 'Demerol'],
#  ['sedation', 'sedation'],
#  ['a-cecal-volvulus',
#   'diarrhea',
#   'methadone',
#   'Fentanyl',
#   '200-mcg',
#   '0-mg',
#   'Phenergan',
#   '25'],
#  ['fluids', '300-mcg', 'fentanyl', '15-mg', 'Versed', 'oxygen'],
#  ['prednisone', '7-mg', '125-mcg', 'fentanyl', 'C-difficile', 'propofol'],
#  ['sedation', 'Colace'],
#  ['heartburn', 'Accupril', 'vitamins'],
#  ['Milk-of-Magnesia', '30-mL', 'daily-p.r.n'],
#  ['depression', 'insulin', 'gallstone', 'Carafate', 'Prilosec', 'metformin'],
#  ['Tramadol',
#   '50-mg',
#   'every-4-to-6-hours-p.r.n',
#   'hydrocodone',
#   'mg/500-mg',
#   'every-6-hours-p.r.n',
#   'zolpidem',
#   '10-mg',
#   'at-bedtime',
#   'triamterene',
#   '37.5-mg',
#   'atenolol',
#   '50-mg',
#   'vitamin-D,-TriCor',
#   '145-mg',
#   'simvastatin',
#   '20-mg',
#   'ibuprofen',
#   '600-mg',
#   't.i.d.',
#   'Lyrica',
#   '75-mg',
#   'legs,-arthritis',
#   'constipation',
#   'bright-red-blood-per-rectum',
#   'constipation',
#   'narcotics',
#   'narcotic-bowel-syndrome.',
#   'statin',
#   'mild-elevations',
#   'complications-such-as-adverse-reaction'],
#  ['lisinopril',
#   '40-mg',
#   'daily',
#   'hydrochlorothiazide',
#   '25-mg',
#   'daily',
#   'metformin',
#   '1000-mg',
#   'twice-a-day',
#   'Januvia',
#   '100-mg',
#   'daily',
#   'clonazepam',
#   '10-mg',
#   'at-bedtime',
#   'restless-legs-syndrome',
#   'Crestor',
#   '10-mg',
#   'Flomax',
#   '0.4-mg',
#   'daily',
#   'restless-legs-syndrome',
#   "Barrett's-esophagus",
#   'sedation'],
#  ['hospital-in-California',
#   'Reglan',
#   '10-mg',
#   'once-a-day',
#   'marginal-ulcers'],
#  ['left-lower-quadrant-pain', 'April', '20'],
#  [],
#  ['Right-upper-quadrant-pain', 'for-one-day'],
#  ['Coumadin', 'hematoma'],
#  ['100-mL', 'intravenous', 'contrast', 'contrast'],
#  ['intravenous',
#   'contrast',
#   'intravenous',
#   'contrast',
#   '100',
#   'Oral',
#   'contrast'],
#  [],
#  ['Flank-pain'],
#  ['intravenous',
#   'contrast',
#   'correlate',
#   'urinary-tract-infection',
#   'correlate',
#   'urinary-tract-infection'],
#  ['Acute-appendicitis'],
#  ['Lower-quadrant-pain'],
#  [],
#  ['CT'],
#  ['intravenous',
#   'contrast',
#   '100-mL',
#   'intravenous',
#   'Isovue-',
#   'Oral',
#   'contrast',
#   'cervix'],
#  ['contrast', '125-cc', 'Omnipaque'],
#  [],
#  ['nausea',
#   'PCA',
#   'Toradol',
#   'nausea',
#   'three-days',
#   'pain-control',
#   'pain-medications',
#   'pain-medication'],
#  ['bladder-spasms',
#   'ciprofloxacin',
#   'for-3-days',
#   'omeprazole',
#   'Colace',
#   'constipation',
#   'Percocet',
#   'pain',
#   'elevated-white-blood-cell-count',
#   'LFTs-were-slightly-elevated',
#   'narcotic-meds',
#   'in-2-weeks'],
#  ['Acute-appendicitis',
#   'acute-appendicitis',
#   'antibiotics',
#   'antibiotics',
#   'heparin',
#   'subcutaneously',
#   'Vicryl',
#   'normal-saline',
#   'saline',
#   'Adaptic',
#   'antibiotics'],
#  ['nitropaste',
#   'morphine',
#   'Lopressor',
#   'positive-results-for-chest-pain',
#   'Lisinopril',
#   '5-mg',
#   'daily',
#   'metoprolol',
#   '25-mg',
#   'twice-daily',
#   'furosemide',
#   '40-mg',
#   'once-daily',
#   'Isentress',
#   '400-mg',
#   'once-daily',
#   'Norvir',
#   '100-mg',
#   'once-daily',
#   'Prezista',
#   '400-mg',
#   'once-daily',
#   'albuterol',
#   'Ambien',
#   '10-mg',
#   'once-daily',
#   'cocaine',
#   'back-discomfort',
#   'extensive-decayed-lower-teeth',
#   'pneumonia',
#   'Nexium',
#   '40-mg',
#   'daily',
#   'GI-prophylaxis',
#   'lisinopril',
#   'metoprolol',
#   'pressor',
#   'Lopressor',
#   '5-mg',
#   'IV-p.r.n.',
#   'metoprolol',
#   'heparin',
#   'oral',
#   'contrast',
#   'oral',
#   'contrast',
#   'aztreonam',
#   '1-g',
#   'every-8-hours',
#   'Flagyl',
#   '500-mg',
#   'every-8-hours'],
#  ['Cetacaine', 'spray,', '100-mcg', 'fentanyl', '5-mg'],
#  ['oxygen',
#   'Synthroid',
#   'Tegretol',
#   'Norvasc',
#   'lisinopril',
#   'DDAVP.',
#   'ASA',
#   'PPI'],
#  ['Fentanyl', '250-mcg', '9-mg', 'sedation'],
#  ['Demerol', 'Versed', 'Demerol', 'Versed', 'sedation'],
#  ['sedation-with', '1', 'lidocaine', 'sedation', 'lidocaine', 'bolus'],
#  ['Cetacaine'],
#  ['sedation'],
#  ['intravenous',
#   'fentanyl',
#   '75-mcg',
#   'intravenous',
#   'Versed',
#   '5-mg',
#   'Cetacaine',
#   'spray',
#   'local-anesthesia'],
#  [],
#  ['Fentanyl',
#   '25-mcg',
#   'Versed',
#   '2-mg',
#   'lidocaine',
#   'spray',
#   'grade-C-esophagitis',
#   'based-ulcers-seen'],
#  ['Fentanyl', '125-mcg', 'Versed', '8-mg', 'recurrent-pain'],
#  [],
#  ['Prevacid'],
#  [],
#  ['Fentanyl',
#   '125-mcg',
#   'Versed',
#   '7-mg',
#   'Aciphex',
#   'Cetacaine',
#   'Aciphex',
#   'a-p.r.n.',
#   'basis'],
#  ['Nexium', '40-mg'],
#  ['lidocaine', 'spray', '5-mg', '100-mcg', 'fentanyl', 'omeprazole'],
#  ['Fentanyl', '100-mcg', '5-mg', 'Versed'],
#  ['Topical-Cetacaine', 'spray'],
#  ['coffee-ground-emesis',
#   'Versed',
#   '4-mg',
#   'fentanyl',
#   '75-mcg',
#   'fundus-of-the-stomach'],
#  ['anticoagulation', 'anesthesia', 'protamine', 'to-reverse-the-heparin'],
#  ['Marcaine', 'Xylocaine', 'Vicryl', 'Vicryl'],
#  ['cimetidine',
#   '400mg',
#   'qhs',
#   'x-5-days',
#   '2-wk',
#   'Tylenol',
#   'prn',
#   '(1-2',
#   'tabs',
#   'every-other-day',
#   'Cimetidine',
#   '400mg',
#   'po',
#   'qhs',
#   '5-days'],
#  [],
#  ['anesthesia',
#   'general-anesthesia',
#   'Vicryl',
#   '4-0',
#   'Monocryl',
#   'Vicryl',
#   'Vicryl',
#   'Vicryl',
#   'Vicryl',
#   'Vicryl',
#   'Monocryl'],
#  ['Iron', 'Z', 'Loveno'],
#  ['anesthesia', 'body-of-the-stomach', 'omeprazole', '20-mg'],
#  ['sedation', '50-mg', 'Demerol', ',-8-mg', 'sedation'],
#  ['right-upper-quadrant-pain',
#   'Demerol',
#   'Versed',
#   'Kinevac',
#   '3-mcg',
#   'Kinevac',
#   'nausea',
#   'previous-pain'],
#  ['Pepcid', 'sedation', 'Demerol', 'Versed'],
#  ['liquid-in-stomach-with-some-fresh-blood-near-the-fundus',
#   'sedation',
#   'fentanyl',
#   '100-mcg',
#   'midazolam',
#   '4-mg',
#   '50-mcg',
#   'fentanyl',
#   '2-mg',
#   'midazolam',
#   'erythromycin',
#   'bright-red-blood-near-the-fundus',
#   'mg',
#   'erythromycin'],
#  ['5-mg',
#   'p.o.',
#   'b.i.d.',
#   'anesthesia',
#   'Z',
#   'Prevacid',
#   '7.5-mg',
#   'p.o.',
#   'b.i.d.'],
#  ['Z'],
#  ["Crohn's-disease",
#   'anesthesia',
#   'aphthous-ulcers',
#   'Begin-prednisone',
#   '30-mg',
#   'p.o.',
#   'daily',
#   'Remicade',
#   '5-mg/kg-IV',
#   'infusion',
#   'Modulon',
#   '50-mL/',
#   'h',
#   'intestine'],
#  ['Demerol', 'intravenously'],
#  ['Vistaril',
#   '50-mg',
#   'Atropine',
#   '4-mg',
#   'IM',
#   'Versed',
#   '5.0-mg',
#   'intravenously',
#   'Cetacaine',
#   'spray'],
#  ['peptic-ulcer-disease',
#   'peptic-ulcer-disease',
#   'sedation',
#   'Demerol',
#   'Versed'],
#  ['Demerol', 'Versed', 'anesthesia', 'flex'],
#  ['sedation',
#   'Xylocaine',
#   'sedation',
#   'Betadine',
#   'Betadine',
#   ',-1',
#   'Xylocaine'],
#  ['lidocaine'],
#  ['Nexium', 'Cetacaine', 'spray'],
#  ['Fentanyl',
#   '200-mcg',
#   'versed',
#   '6-mg',
#   'nonsteroidal-anti-inflammatory-medication'],
#  ['Demerol',
#   'Versed',
#   'Demerol',
#   'Versed',
#   'sedation',
#   'b.i.d-proton-pump-inhibitor'],
#  ['anesthesia', 'coin', 'one-unit'],
#  ['foreign-body', 'Intravenous', 'fluids'],
#  ['anesthesia'],
#  [],
#  ['hemostasis-down-to-the-fascia'],
#  [],
#  [],
#  [],
#  ['barium-enema-prep-and-lidocaine-ointment'],
#  [],
#  ['Reglan',
#   'Prilosec',
#   'Pepcid',
#   'Carafate',
#   'Bactrim',
#   'UTI',
#   'Cipro',
#   '500-mg',
#   'b.i.d.',
#   'Omeprazole',
#   '20-mg',
#   'daily',
#   'famotidine',
#   '20'],
#  ['problems-related'],
#  ['constipation',
#   'fluid',
#   'bolus',
#   'Albuterol',
#   ',-Pulmicort,-MiraLa',
#   'x',
#   '17-g',
#   'once-a-week',
#   'carnitine',
#   'Depakene',
#   'Reglan',
#   'vitamin-K',
#   'FFP',
#   'blood-transfusion'],
#  ['diabetes-type-2',
#   'chronic-obstructive-pulmonary-disease',
#   'fluids',
#   'prednisone',
#   '60-mg',
#   'p.o.',
#   'Prandin',
#   'Actos',
#   'Lipitor',
#   'Benicar',
#   'Advair',
#   'tapered-dose',
#   'prednisone',
#   'for-4-weeks',
#   '15-mg',
#   'p.o',
#   'seven-days',
#   '40-mg',
#   'for-1-week',
#   '30-mg',
#   'for-1-week',
#   '20-mg',
#   'for-1-week',
#   'tapered-dose',
#   'prednisone',
#   'for-4-weeks'],
#  ['Cardizem-CD', '240-mg', 'eye', 'drops', 'irritation-in-the-rectal-area'],
#  ['Gastrointestinal-bleed',
#   'Imdur',
#   'metoprolol',
#   'Synthroid',
#   'Plavix',
#   'Protoni',
#   'Prilosec',
#   'Protonix',
#   'Prilosec',
#   'Pepcid',
#   '40-mg',
#   'at-night',
#   'Imdur',
#   'Synthroid',
#   'metoprolol',
#   'Plavix',
#   'Pepto'],
#  ['Gastrointestinal-bleed',
#   'very-dark-stools',
#   'Lipitor',
#   'Lasix',
#   'Toprol',
#   'Diphenhydramine',
#   'Ibuprofen',
#   'Daypro',
#   'p.r.n.',
#   'insulin',
#   'ibuprofen',
#   'Daypro',
#   'peptic-ulcer-disease',
#   'Gastrointestinal-bleed',
#   'lower-gastrointestinal-bleed',
#   'peptic-ulcer-disease',
#   'Diabetes-mellitus',
#   'sliding-scale',
#   'as-needed'],
#  ['proton-pump-inhibitor'],
#  ['Reglan', '10-mg', 'three-to-four-times-a-day'],
#  [],
#  ['PPI'],
#  ['anesthetic', 'Vicryl'],
#  ['atrial-fibrillation',
#   'Coumadin',
#   'insulin',
#   'diabetes-mellitus',
#   'Coumadin',
#   'Coumadin',
#   'additional-three-days',
#   'insulin',
#   'Feosol',
#   '325-mg',
#   'daily',
#   'multivitamins-one',
#   'daily',
#   'Protonix',
#   '40-mg',
#   'b.i.d',
#   'KCl',
#   '20-mEq',
#   'daily',
#   'Lasix',
#   '40-mg',
#   'b.i.d.',
#   'atenolol',
#   '50-mg',
#   'daily',
#   'Synthroid',
#   '80-mcg',
#   'daily',
#   'Actos',
#   '30-mg',
#   'daily',
#   'Mevacor',
#   '40-mg',
#   'daily',
#   'lisinopril',
#   '20-mg',
#   'daily',
#   'Coumadin'],
#  ['itching', 'April', '18,-200', 'inflammatory-arthritis'],
#  ['Eugene',
#   'right-upper-quadrant-pain',
#   'mild-gastritis',
#   'Zofran',
#   'Sulfa',
#   'Codeine',
#   'Juvenile-rheumatoid-arthritis',
#   'anti-inflammatory',
#   'Zofran',
#   'Eugene',
#   'elevated-liver-function-tests'],
#  ['Imuran',
#   '100-mg',
#   'intermittent-obstructive-symptoms',
#   'Tylenol',
#   'migraine-type-headaches',
#   'Imuran',
#   'for-one-month',
#   'Tylenol',
#   '2-blockers',
#   'Imuran',
#   'Nascobal',
#   'Vicodin',
#   'p.r.n',
#   'Imuran',
#   'Tylenol',
#   'Imuran',
#   '100-mg',
#   'Tylenol',
#   'migraines',
#   'aspirin',
#   'migraine-headaches',
#   'daily',
#   'Zantac',
#   '150-mg'],
#  ['sharp-stabbing-pain', 'Oral', 'pharyn'],
#  ['anesthesia', 'antibiotics', 'side', 'Vicryl', 'Additional-sterile-saline'],
#  ['pain-in-the-area-with-headache', 'lactulose', 'Dilantin', 'lactulose'],
#  ['Right-upper-quadrant-pain', '2.1-mcg', 'intravenous'],
#  ['aspiration-pneumonia',
#   'Heart-rate-in-the-100s-to-120s-at-times-with-atrial-fibrillation'],
#  [],
#  ['Four-hours',
#   'Betadine',
#   'right-upper-quadrant',
#   'intravenous',
#   'mannitol',
#   '8000-units',
#   'intravenous',
#   'sodium-heparin',
#   '70-mg',
#   'intravenous',
#   'protamine',
#   'bacitracin',
#   'kanamycin'],
#  ['right-upper-quadrant-pain',
#   'fluid',
#   'low-dose',
#   'antibiotic',
#   'chronic-bronchitis',
#   'Synthroid',
#   '0.5-mg',
#   '1',
#   'tablet',
#   'p.o.',
#   'daily',
#   'Plavix',
#   '75-mg',
#   'p.o.',
#   'daily',
#   'folic-acid',
#   '1-mg',
#   'p.o.',
#   'daily',
#   'Diovan',
#   '80-mg',
#   'p.o.',
#   'daily',
#   'Renagel',
#   '2',
#   'tablets',
#   '800-mg',
#   'p.o.',
#   'twice-a-day',
#   'Lasix',
#   '40-mg',
#   'p.o',
#   'tablets',
#   'twice-a-day',
#   'lovastatin',
#   '20-mg',
#   'p.o.',
#   'daily',
#   'Coreg',
#   '3.125-mg',
#   'p.o.',
#   'twice-a-day',
#   'nebulizer',
#   '3-hours-as-needed',
#   'Phenergan',
#   '25-mg',
#   'p.o.',
#   'q.8-hours',
#   'nausea-and-vomiting',
#   'Pepcid',
#   '20-mg',
#   'p.o.',
#   'daily',
#   'Vicodin',
#   '1',
#   'tablet',
#   'p.o.',
#   'q.6-hours-p.r.n',
#   'as-needed',
#   'Levaquin',
#   '250-mg',
#   'p.o.',
#   'every-other-day',
#   'for-the-next-5-days',
#   'Premarin'],
#  ['Acute-appendicitis',
#   'Acute-appendicitis',
#   'antibiotics',
#   'Betadine',
#   '0.25',
#   'Marcaine'],
#  ['Acute-appendicitis', 'usual-sterile-fashion', 'Vicryl', '5-0-Monocryl'],
#  [],
#  ['endotracheal-intubation', 'Marcaine', 'Vicryl', 'Monocryl'],
#  ['Acute-appendicitis',
#   'Acute-appendicitis',
#   'constipation',
#   'polyethylene-glycol',
#   'boluses',
#   'fluid',
#   'uneventful-induction-of-general-anesthesia',
#   '25',
#   'Marcaine',
#   'Monocryl',
#   'Monocryl'],
#  ['lower-quadrant-pain', 'usual-sterile-fashion', '0.25', 'Marcaine'],
#  ['anesthesia', 'Monocryl'],
#  ['Vicryl', 'Monocryl', '0.', 'Marcaine', 'epinephrine'],
#  ['back-pain', 'Vicryl', 'Vicryl', '25', 'Marcaine'],
#  ['anesthesia'],
#  ['anesthesia'],
#  ['anesthesia', 'Marcaine', '4-0', 'Monocryl'],
#  ['endotracheal-intubation', 'Marcaine', 'Marcaine', 'Monocryl'],
#  ['endotracheal-intubation', 'Marcaine', 'Vicryl', 'Monocryl'],
#  ['1-gm',
#   'extrahepatic-biliary-trees',
#   'contrast',
#   'saline',
#   'Vicryl',
#   'Vicryl'],
#  ['Crystalloid',
#   'general-endotracheal-anesthesia',
#   '1%',
#   'lidocaine',
#   'ropivacaine',
#   'Monocryl'],
#  ['Vicryl', 'Marcaine', 'Vicryl', 'benzoin'],
#  ['bleeding,-infection',
#   'general-endotracheal-anesthesia',
#   '0.25',
#   'bupivacaine',
#   'epinephrine',
#   'Vicryl-Rapide',
#   'Mastisol,-Steri'],
#  ['anesthesia', 'right-upper-quadrant'],
#  ['Vicryl',
#   'fine',
#   '0.5',
#   'Marcaine',
#   '0.5',
#   'Marcaine',
#   'saline',
#   'Vicryl',
#   'benzoin'],
#  ['Marcaine',
#   'lidocaine',
#   'right-upper-quadrant-pain',
#   'antibiotics',
#   'Kefzol',
#   'Vicryl'],
#  ['Marcaine', 'Vicryl', '2-L', 'saline', 'Monocryl'],
#  ['endotracheal-intubation',
#   'Marcaine',
#   'hole-in-the-duodenogastric-limb',
#   'Brolin',
#   'anti-obstruction-stitch',
#   'Anesthesia',
#   'Vicryl',
#   'Monocryl'],
#  ['Acute-suppurative-appendicitis',
#   'lidocaine',
#   'Marcaine',
#   'nausea-associated-with-it.',
#   'acute-appendicitis',
#   'Ancef',
#   '1-gram',
#   'Vicryl'],
#  ['40-cc', 'sterile-saline', 'Vicryl', '0.', '25', 'Marcaine', 'antibiotics'],
#  ['anesthesia',
#   'local-anesthesia',
#   'Vicryl',
#   'Vicryl',
#   'outside',
#   'Vicryl',
#   'Vicryl',
#   '20-mL',
#   'Marcaine',
#   'epinephrine',
#   'postoperative-pain-control',
#   'Vicryl',
#   'Vicryl'],
#  ['Lidocaine',
#   'iodine',
#   'lidocaine',
#   'codeine',
#   'povidone-iodine',
#   'lidocaine',
#   'four-to-six-hours'],
#  ['right-lower-quadrant-pain',
#   'Hydrochlorothiazide',
#   '25-mg',
#   'p.o.',
#   'Lisinopril',
#   '10-mg',
#   'p.o.',
#   'Albuterol',
#   'p.r.n.',
#   'mild-discomfort',
#   'Abdominal-pain'],
#  ['2-units',
#   'PRBCs',
#   '2-units',
#   'packed-red-blood-cells',
#   'proton-pump-inhibitor',
#   'avoid-NSAIDs',
#   'creatinine',
#   'ferritin',
#   '27',
#   'occult-blood-positive',
#   'oral',
#   'Omnicef',
#   'azithromycin',
#   'guaifenesin',
#   'N-acetyl',
#   'oral',
#   'antibiotics',
#   'iron,-vitamin-C',
#   'folate'],
#  ['congestive-heart-failure'],
#  ['Antibiotics', 'Vicryl', 'Marcaine', '0.5', 'postanesthetic-pain-control'],
#  ['steroid-dependent-COPD', 'lidocaine'],
#  ['Zofran',
#   'Phenergan',
#   'oral',
#   'hypoglycemics',
#   'insulin',
#   'sliding-scale',
#   'chemotherapy',
#   'chemotherapy-in-metastatic-pancreatic-cancer',
#   'Phenergan',
#   '25-mg',
#   'q.6.',
#   'Duragesic',
#   'patch',
#   'Benadryl',
#   '25-50-mg',
#   'p.o.',
#   'q.i.d.',
#   'Sliding-scale'],
#  ['chemotherapy'],
#  ['5500'],
#  ['sedation'],
#  ['anesthesia', 'anesthesia'],
#  ['HIV-infection',
#   'past-six-months',
#   'blood',
#   '82-U',
#   'anal-swab',
#   'proctitis',
#   'ceftriaxone',
#   'C-trachomatis',
#   'Ceftriaxone',
#   'resistant-N-gonorrhoeae',
#   'HIV-infection'],
#  ['viral-infection',
#   'creatinine',
#   'calcium',
#   'Epigastric-pain',
#   'chronic-pain-syndrome',
#   'opiates',
#   'End-stage-liver-disease',
#   'Alpha',
#   '1',
#   '-antitrypsin-deficiency',
#   'lactulose',
#   '50-mL',
#   '3-times-daily',
#   'opiates',
#   'Inderal',
#   '10-mg',
#   '10-mg',
#   'twice-daily',
#   'Inderal'],
#  ['bright-red-blood-in-the-stool',
#   'soft-and-consistent-with-dark-red-blood-in-it.',
#   'Zantac'],
#  ['stomach-discomfort', 'Lomotil', 'Levaquin', 'PPI', 'PUD-prophylaxis'],
#  ['Fentanyl-(Sublazine',
#   ')-0.',
#   'mg',
#   'Versed-(midazolam',
#   'mg',
#   'adverse-medication'],
#  ['AF-reports-10/10-pain',
#   'Iodine',
#   'contrast',
#   'One-question',
#   'patients-with-mechanical-obstruction'],
#  ['tetracycline', 'Reglan', '2-units', 'packed-red-blood-cells'],
#  ['Ethanol',
#   'Ethanol',
#   'Thirty-ml',
#   'ethanol',
#   '1-gram',
#   'Ancef',
#   'Vanderbilt'],
#  ['molar-pain',
#   'Prograf',
#   '0.5-mg',
#   'p.o.',
#   'Valganciclovir',
#   '420-mg',
#   'p.o.'],
#  ['anesthetic'],
#  ['anesthesia', 'intravenous', 'antibiotics', '25-mL'],
#  ['Xylocaine', '1', 'saline'],
#  ['right-upper-lobe-pneumonia'],
#  [],
#  ['0.25', 'Marcaine', '2-0', 'Vicryl', 'subcutaneous'],
#  ['adequate-local-anesthetic-was-administered-using-1%-lidocaine-without-epinephrine',
#   'Vicryl',
#   'sterile-saline',
#   'benzoin'],
#  ['Coumadin',
#   'Versed',
#   '2-mg',
#   'fentanyl',
#   '50-mcg',
#   'distal-esophagus',
#   'propofol-sedation',
#   'bolus',
#   'longstanding-bolus',
#   'Coumadin',
#   'Protonix',
#   '40-mg',
#   'q.12h',
#   'Prevacid-SoluTab',
#   'mg',
#   'b.i.d.'],
#  ['foreign-body-removal'],
#  ['fine',
#   'fluoxetine',
#   '2-L',
#   'Compazine',
#   '5-mg',
#   '2',
#   'two-capsules',
#   'Imodium',
#   'Compazine',
#   '10-mg',
#   'tabs',
#   'one',
#   'p.o.',
#   'q.8',
#   'p.r.n.',
#   'recurrent-nausea',
#   'liquids',
#   'Imodium'],
#  ['refractory-ulcerative-colitis',
#   'wound-infection',
#   'Percocet',
#   'pain',
#   'Tylenol',
#   'intermittent-pain',
#   'pain-medications',
#   'refractory-ulcerative-colitis',
#   'Percocet',
#   'Percocet',
#   'ibuprofen',
#   'Tylenol',
#   'pain'],
#  ['procardia-SR',
#   'Lasix',
#   'Ecotrin',
#   'Digoxin',
#   'Colace',
#   'Coumadin',
#   'coumadin',
#   'Coumadin'],
#  ['Ambien',
#   'Codeine',
#   'Premarin',
#   '0.625-mg',
#   'p.o.',
#   'q.o.d.',
#   'Aciphex',
#   '20-mg',
#   'p.o.',
#   'q.-daily',
#   'Toprol',
#   '50-mg',
#   'p.o.',
#   'q.-daily',
#   'Norvasc',
#   '5-mg',
#   'p.o.',
#   'q.-daily',
#   'multivitamin',
#   'Caltrate',
#   'B-complex-vitamins',
#   'calcium',
#   'magnesium',
#   'vitamin-C',
#   'daily',
#   'for-four-days',
#   'spinal-catheter-protocol'],
#  ['MMSE', 'Muscatine', 'anxiety'],
#  ['anaplastic-astrocytoma',
#   'term-side-effects',
#   'chemotherapy',
#   'eight-possible-agents',
#   'steroids',
#   'sq-m',
#   'everyday',
#   'thalidomide',
#   '100',
#   'for-one-week'],
#  ['for-3-weeks',
#   'Phenobarbital',
#   'Dilantin',
#   'Depakene',
#   'poor-seizure-control',
#   'Tegretol',
#   'Dilantin',
#   'Phenobarbital',
#   'Depakote',
#   'Acetazolamide',
#   'Mysoline',
#   'Dilantin',
#   'Tegretol'],
#  ['daily',
#   'neck-pain',
#   'Medrol',
#   'caused-his-blood-sugars',
#   'ACTOplus',
#   'albuterol',
#   'Astelin',
#   'Diovan',
#   'aspirin',
#   '81-mg',
#   'fish-oil',
#   'Lipitor',
#   'Lorazepam',
#   'multivitamins',
#   'Nasacort',
#   'Pulmicort',
#   'ranitidine',
#   'Singulair',
#   'Viagra',
#   'Zetia',
#   'Zyrtec',
#   'Lidoderm',
#   'patches',
#   'Dyazide',
#   'Zithromax',
#   'amoxicillin',
#   'intermittent-chest-discomfort',
#   'Deep-Tendon-Reflexes',
#   'Neurontin'],
#  [],
#  ['ASA', 'gadolinium-contrast', 'Decadron'],
#  ['nausea', 'positional-change'],
#  ['Demerol',
#   'codeine',
#   'Lotensin',
#   'metoprolol',
#   'Darvocet',
#   'Synthroid',
#   'Zocor',
#   'Valtrex',
#   '1-g',
#   't.i.d.',
#   'for-seven-days',
#   'steroids'],
#  ['Peripheral-vascular-disease',
#   'Peripheral-vascular-disease',
#   'local-anesthesia',
#   'Heparin',
#   'protamine'],
#  ['1.0mg',
#   'normal-saline',
#   'orthostatic-hypotension',
#   'Aldosterone',
#   'Prolactin',
#   '15.',
#   'Fludrocortisone',
#   '0.05-mg',
#   'BID',
#   'fluids',
#   'orthostatic-hypotension',
#   'Fludrocortisone'],
#  ['dystonic-tremor',
#   'deep-brain-stimulation',
#   'Betadine',
#   '5',
#   'Marcaine',
#   'lidocaine',
#   'antibiotics',
#   'administered-as-was-the-sedation',
#   'Betadine',
#   'Vicryl'],
#  [],
#  ['nausea', 'Tylenol', 'Advil'],
#  ['Prozac',
#   'Ativan',
#   'left-lateral-medullary-stroke',
#   'Heparin',
#   'Coumadin',
#   'Coumadin',
#   'for-3-months',
#   'ASA',
#   'for-1-year'],
#  ['bacterial-meningitis'],
#  ['Colace',
#   'Quinidine',
#   'Synthroid',
#   'Lasix',
#   'Lanoxin',
#   'Tenormin',
#   "Briquet's-syndrome",
#   'chlorambucil',
#   'prednisone-chemotherapy',
#   '5-more-cycles',
#   'chlorambucil',
#   'prednisone'],
#  ['chronic-allergic-rhinitis-symptoms',
#   'Flonase',
#   'two-sprays',
#   'each-nostril',
#   'once-a-day',
#   'Zyrtec',
#   '10-mg',
#   'penicillin'],
#  ['amoxicillin',
#   'low-back-pain',
#   '10-day',
#   'Cipro',
#   'UTI',
#   'Cipro',
#   'Aleve',
#   'aspirin',
#   'multivitamin',
#   'iron',
#   'aspirin',
#   'BACK'],
#  ['steroid', 'injections', 'improve-her-symptoms'],
#  ['Lipitor',
#   'Pulmicort',
#   'Allegra',
#   'Xopenex',
#   ',-Patanol,-Duac-topical-gel,',
#   'Loprox',
#   'cream',
#   'Penicillin',
#   'aspirin',
#   'mild-postural-tremor-in-both-arms'],
#  ['Mestinon',
#   '30mg',
#   'tid',
#   '60mg',
#   'tid',
#   '30mg',
#   'tid',
#   'Viokase',
#   'Probenecid',
#   'Mestinon',
#   '30mg',
#   'tid',
#   'XRT'],
#  ['human-resources-consultant',
#   'legs-seemed-to-worsen-somewhat',
#   'Avonex',
#   'for-about-six-months',
#   'baclofen',
#   'Medrol-Dosepak',
#   'intravenous-Solu-Medrol',
#   '500-mg',
#   'daily',
#   'for-five-days',
#   'prednisone',
#   'Medrol',
#   'taper',
#   'steroids',
#   'April',
#   '20',
#   'Zanaflex',
#   'oral',
#   'prednisone',
#   '10-mg',
#   'tablets',
#   'one-half',
#   'tablet',
#   'daily',
#   'to-reduce-the-swelling',
#   'prednisone',
#   'relief-of-the-spasticity',
#   'VICODIN',
#   "Dawson's-fingers",
#   '5-point-scale',
#   'oral',
#   'steroids',
#   'steroids',
#   'obvious-side-effects',
#   'steroids',
#   'Zanaflex',
#   'baclofen',
#   'Neurontin',
#   'mg',
#   'b.i.d.-or-t.i.d',
#   'needed-up-to-300',
#   'mg',
#   'b.i.d.-or-t.i.d',
#   'four-times-daily',
#   'Neurontin',
#   'Klonopin',
#   '0.',
#   'mg-1-mg',
#   't.i.d.',
#   'q.i.d',
#   'Valium',
#   '5-10-mg',
#   't.i.d.',
#   'q.i.d.',
#   'Copaxone',
#   'methotrexate',
#   'CellCept',
#   'weekly',
#   'for-six-weeks'],
#  ['Aricept',
#   'frank-depression',
#   'movement-disorders',
#   'Fiorinal,-p.r.n',
#   'aspirin',
#   'Premarin',
#   'America',
#   'some-right-knee-pain',
#   'right-knee-pain',
#   'Aricept',
#   'Aricept',
#   'Aricept',
#   'Aricept',
#   'Aricept',
#   '10-mg',
#   'a-day'],
#  ['Plavix',
#   'aspirin',
#   'levothyroxine',
#   'lisinopril',
#   'hydrochlorothiazide',
#   'Lasix',
#   'insulin',
#   'simvastatin',
#   'joint-pain',
#   'antiplatelet-therapy',
#   'statin'],
#  ['Aleve', 'six-hours', 'depression', 'symptoms-worsen'],
#  ['Topamax',
#   'Maxalt',
#   'migraine',
#   'prednisone',
#   '50-mg',
#   'migraine-prophylaxis',
#   'Fioricet',
#   'p.r.n.',
#   'basis'],
#  ['Aricept',
#   '10-mg',
#   'in-the-evening',
#   'carbidopa',
#   'levodopa',
#   '25/100-mg',
#   'three-times-a-day',
#   'citalopram',
#   'Celexa)',
#   '40-mg',
#   'daily',
#   'Colace',
#   '100-mg',
#   'twice-a-day',
#   'finasteride',
#   'Proscar)',
#   '5-mg',
#   'once-a-day',
#   'Flomax',
#   '(tamsulosin)',
#   '4-mg',
#   'once-a-day',
#   'multivitamin',
#   'iron',
#   'once-a-day',
#   'omeprazole',
#   'Prilosec)',
#   '20-mg',
#   'once-a-day',
#   'senna',
#   '8.6-mg',
#   'twice-a-day',
#   'Tylenol',
#   '650-mg',
#   'as-needed',
#   'promethazine',
#   '25-mg',
#   'as-needed'],
#  ['generalized-tonic-clonic-seizure',
#   'Trileptal',
#   'Keppra',
#   'lamotrigine',
#   'seizure',
#   'minor-headaches',
#   'Lamotrigine',
#   '150-mg',
#   'p.o.',
#   'b.i.d.',
#   'verapamil',
#   'hydrochlorothiazide',
#   'Flagyl',
#   'aspirin',
#   'lamotrigine',
#   'lamotrigine',
#   '150-mg',
#   'p.o.',
#   'lamotrigine'],
#  ['Carbatrol',
#   '300-mg',
#   'b.i.d.',
#   'Avapro',
#   'lisinopril',
#   'Carbatrol',
#   '200',
#   'b.i.d.',
#   'obstructive-sleep-apnea'],
#  ['Synthroid', '100-mcg'],
#  ['usual-manner-with-Betadine-soak-scrub',
#   'Cavitron',
#   'Subcutaneous',
#   'Vicryl',
#   'Vicryl',
#   '2-units',
#   'packed-red-cells',
#   '3-L'],
#  ['usual-sterile-fashion', 'anesthesia'],
#  ['usual-manner-with-Betadine-soaked-scrub', '2-0', 'Vicryl'],
#  ['acute-leukemia', 'Betadine', 'iodine', 'saline', 'closing-the-skin'],
#  ['anesthesia',
#   'localize-the-tumor',
#   'mannitol',
#   'malignant-brain-tumor',
#   'Vicryl'],
#  ['anesthetic', 'Xylocaine', 'epinephrine', 'Bergen-retractors'],
#  ['Labbe', 'skin-closure'],
#  ['non-small-cell-carcinoma-of-the-lung', 'Cavitron', '150-mL'],
#  ['assassin', 'double-simultaneous-stimulation'],
#  ['Staphylococcus-Aureus',
#   'oxacillin',
#   'Nafcillin',
#   '2gm',
#   'IV',
#   'q4',
#   'Rifampin',
#   '600mg',
#   'q',
#   '12hrs',
#   'Gentamicin',
#   '130mg',
#   'q12hrs',
#   'Mannitol'],
#  ['Selverstone-Clamp', 'Nimodipine'],
#  ['insulin',
#   'NPH-Humulin',
#   '1',
#   '2U',
#   'qAM-and-6U-qPM',
#   'Advil',
#   'prn',
#   'microglobulin',
#   'Iron',
#   '3',
#   'ASA',
#   '325mg',
#   'qd'],
#  ['chills/night-sweats/CP',
#   'Lithium',
#   '300mg',
#   'bid',
#   'Accupril',
#   '20mg',
#   'bid',
#   'ASA',
#   '325mg',
#   'qd'],
#  ['severe-headache',
#   'Oral-Contraceptive-pill-QD.EXAM',
#   'neck-pain',
#   'central-venous-thrombosis'],
#  ['Micronase', '5mg', 'qd', 'HCTZ', 'ASA', 'DM-type-2'],
#  ['meclizine', 'Meclizine'],
#  ['ASA', 'Dilantin', 'seizure-prophylaxis', 'Tenormin', 'Premarin', '2mcg/ml'],
#  [],
#  [],
#  [],
#  [],
#  ['Seizure-disorder'],
#  [],
#  [],
#  ['intravenous', 'contrast'],
#  ['CONTRAST', 'muscle-spasms'],
#  ['facet'],
#  [],
#  [],
#  ['facet'],
#  [],
#  ['intravenous', 'contrast'],
#  ['confused',
#   'UTI',
#   'amoxacillin',
#   'empiric-Vitamin-B12',
#   '1000mcg',
#   'IM',
#   'qd',
#   '7-days',
#   'Thiamine',
#   '100mg',
#   'qd',
#   'Folate',
#   '1mg',
#   'qd',
#   'ASA',
#   '325mg',
#   'qd',
#   'UTI',
#   'contrast',
#   'Vitamin-B'],
#  ['Thrombocytopenia',
#   'Plavix',
#   'aspirin',
#   'oral',
#   'Zithromax',
#   'cough',
#   'Xopenex',
#   'respiratory-distress',
#   'cough',
#   'Zithromax',
#   'albuterol',
#   'Zithromax'],
#  ['Plavix',
#   'aspirin',
#   'slurred-speech',
#   'Z-Pak',
#   'cortisone-shot',
#   'Ibuprofen',
#   'p.r.n.',
#   'Chronic-neck-pain'],
#  ['seizures', '200mg'],
#  ['Transcatheter-infusion',
#   'papaverine',
#   'anesthesia',
#   'entire-duration',
#   'continuous-heparinized-saline-flush',
#   'continuous-heparinized-saline-flush',
#   'mg',
#   'papaverine',
#   'papaverine'],
#  ['supraorbital-pain'],
#  ['Bilateral-lower-extremity-cellulitis',
#   'Valium',
#   '10-20-mg',
#   'at-bedtime',
#   'Flomax',
#   '0.4-mg',
#   'daily',
#   'cefazolin',
#   '500-mg',
#   'q.i.d.,-and',
#   'Lotrimin',
#   'cream-between-toes-b.i.d',
#   'lower-extremity-cellulitis',
#   'intravenous',
#   'ceftriaxone',
#   'Lotrimin',
#   '500-cc',
#   'Flomax',
#   '0.4-mg',
#   'daily'],
#  ['potassium',
#   'Pravachol',
#   'Prevacid',
#   'Synthroid',
#   'Diovan',
#   'Amaryl',
#   'Vitamin-B',
#   'Coreg',
#   'Coumadin',
#   'furosemide',
#   'Actos',
#   'aspirin',
#   'colchicine',
#   'Cipro',
#   'Percocet',
#   'Ultram',
#   'Diabetes-and-hypothyroidism',
#   'numb-in-both-feet',
#   'brain-stroke-and-vertebrobasilar-insufficiency'],
#  ['Zantac',
#   '150mg',
#   'bid',
#   'Proventil',
#   'MDI-bid',
#   'Azmacort-MDI',
#   'bid',
#   'Doxycycline',
#   '100mg',
#   'bid',
#   'Premarin',
#   '0.625mg',
#   'qd',
#   'Provera',
#   '2.5mg',
#   'qd',
#   'ASA',
#   '325mg',
#   'qd',
#   'GERD',
#   'heme-positive-stool',
#   'Ticlid',
#   '250mg',
#   'bid'],
#  ['generalized-cerebral-disorder'],
#  ["patient's-medications-valproic-acid", 'Zonegran', 'Keppra', 'One-clinical'],
#  [],
#  [],
#  [],
#  ['sleepy-state'],
#  ['Depakene'],
#  ['seizures'],
#  ['amitriptyline'],
#  ['Lyrica'],
#  [],
#  ['Medrol-Dosepak', 'spinal-epidural-injections'],
#  ['Neurontin', 'Lidoderm', 'patch', 'C-spine-and-T-spine'],
#  ['pain',
#   'steroid',
#   'injections-in-her-neck',
#   'rheumatoid-arthritis',
#   'C-spine',
#   'carpal-tunnel-release'],
#  [],
#  ['low-neck-pain'],
#  [],
#  ['Motor-units', 'Motor-units', 'Motor-units'],
#  ['Tylenol', 'as-needed', 'Colace', 'b.i.d.', 'Tylenol', 'pain'],
#  ['bradycardia', 'Mannitol', '1g', 'Dilantin'],
#  ['Lasix',
#   '40mg',
#   'qd',
#   'Zantac',
#   '150mg',
#   'qd',
#   'Lanoxin',
#   '0.125mg',
#   'qd',
#   'Capoten',
#   '2.5mg',
#   'bid',
#   'Salsalate',
#   '750mg',
#   'tid',
#   'ASA',
#   '325mg',
#   'qd',
#   'Ginseng)',
#   '100mg',
#   'bid',
#   'DVT'],
#  ['sternal-abscess', 'minor-myocardial-infarction', 'accept', 'one', 'saline'],
#  ['propranolol',
#   'for-the-tremor',
#   'primidone',
#   'clonazepam',
#   'anxiety',
#   'migraine-headaches-without-aura',
#   'Klonopin',
#   '0.',
#   'Primidone',
#   '100'],
#  ['Darvocet',
#   'anxiety',
#   'Paxil',
#   'Xanax',
#   'Tylenol',
#   '650-mg',
#   'q.6',
#   'p.r.n.',
#   'Xanax',
#   '0.',
#   'q.4h.-p.r.n.',
#   'Lasix',
#   '80-mg',
#   'daily',
#   'Isordil',
#   '10-mg',
#   't.i.d',
#   'KCl',
#   '20-mEq',
#   'b.i.d.',
#   'lactulose',
#   '10-g',
#   'daily',
#   'Cozaar',
#   '50-mg',
#   'daily',
#   'Synthroid',
#   '75-mcg',
#   'daily',
#   'Singulair',
#   '10-mg',
#   'daily',
#   'Lumigan',
#   'one',
#   'drop',
#   'Pravachol',
#   '20-mg',
#   'daily',
#   'Feldene',
#   '20-mg',
#   'daily',
#   'Paxil',
#   '20-mg',
#   'daily',
#   'Minipress',
#   '2-mg',
#   'daily',
#   'Provera',
#   'Advair',
#   '2',
#   'one',
#   'puff',
#   'b.i.d',
#   'one',
#   'tablet',
#   'b.i.d.',
#   'Timoptic',
#   'one',
#   'drop',
#   'OU',
#   'daily',
#   'verapamil',
#   '80-mg',
#   'b.i.d.'],
#  ['relieve-the-discomfort',
#   'Bactrim',
#   'antiretroviral-medications',
#   'insulin',
#   'Bactrim',
#   'Bactrim',
#   'Bactrim',
#   'Bactrim',
#   'Neurontin',
#   'taper-the',
#   'mg',
#   't.i.d.',
#   'Neurontin',
#   'Bactrim'],
#  ['Plavix',
#   '75-mg',
#   'p.o',
#   'metoprolol',
#   '25-mg',
#   'p.o.',
#   'q.d.',
#   'Flomax',
#   '0.4-mg',
#   'p.o',
#   'Zocor',
#   '20-mg',
#   'p.o.',
#   'q.d.',
#   'Detrol',
#   'LA-4-mg',
#   'p.o',
#   'lisinopril',
#   '10-mg',
#   'p.o.',
#   'q.d.',
#   'Imodium',
#   'daily',
#   'Omega-3',
#   'Lasix'],
#  ['contrast', '20', '8-mg', 'Decadron', 'prophylaxis'],
#  ['somnolent',
#   'iron',
#   'ACE',
#   'SPEP',
#   'steroids',
#   'gadolinium-contrast',
#   'somnolent'],
#  ['BCNU-chemotherapy'],
#  ['Tylenol',
#   '500mg',
#   'q5-6',
#   '2,-2RBC,-1WBC.',
#   'gadolinium',
#   'x',
#   '4.0',
#   '0.8units'],
#  ['intravenous',
#   'gamma-globulin',
#   'three-times-per-week',
#   'Percocet',
#   '5',
#   'mg',
#   '4-6-hours-p.r.n',
#   'Neurontin',
#   '100-mg',
#   'insulin',
#   'Protoni',
#   '40-mg',
#   'Toprol-XL',
#   '50-mg',
#   'q.d.',
#   'Norvasc',
#   '10-mg',
#   'q.d.',
#   'glipizide',
#   '10-mg',
#   'q.d.',
#   'fluticasone',
#   '50-mcg',
#   'nasal',
#   'spray',
#   'Lasix',
#   'mg',
#   'b.i.d.',
#   'Zocor',
#   '1-mg',
#   'q.d.ALLERGIES:',
#   'right-upper-extremity',
#   'Barre-syndrome',
#   'IVIG',
#   'back-pain',
#   'Neurontin',
#   'Neurontin',
#   '300-mg',
#   '300-mg',
#   'b.i.d.',
#   'baclofen',
#   'Percocet',
#   'aspirin',
#   '162-mg',
#   'Neurontin',
#   '300-mg',
#   'per-day',
#   'x-1-week',
#   'mg'],
#  ['AM,-Sunday-morning'],
#  ['cataclysmic-headache',
#   'left-upper-eyelid-began-to-droop',
#   'Lanoxin',
#   'Lasix',
#   'KCL',
#   'ASA',
#   'Voltaren',
#   'DL-(high)',
#   'prednisone'],
#  ['Spine', 'Dilantin', 'Zantac', 'Proventil-MDI', 'Tylenol', 'pyelonephritis'],
#  ['Zonegran',
#   'mg',
#   'q.h.s.',
#   'Zonegran',
#   'localized-pain',
#   'Motrin',
#   '400-mg',
#   'b.i.d.',
#   'diabetes-control',
#   'Glyburide',
#   'Avandia',
#   'metformin',
#   'lisinopril',
#   'Lipitor',
#   'aspirin',
#   'metoprolol',
#   'Zonegran',
#   'Zonegran',
#   'mg',
#   'q.h.s.',
#   'Zonegran',
#   'Neurontin',
#   'Lyrica',
#   'diabetes-control'],
#  ['One-unit', 'packed-red-blood-cells', 'Vicryl', 'Vicryl'],
#  ['pain-in-the-area-with-headache', 'lactulose', 'Dilantin', 'lactulose'],
#  ['Sertraline',
#   'Fluoxetine',
#   'Fluoxetine',
#   'Huntington-Disease',
#   '(d',
#   'Elavil',
#   '25mg',
#   'qhs'],
#  ['Haldol',
#   'tablets',
#   '5-mg',
#   'Tylenol',
#   'tablet',
#   'worsening-depression',
#   'Pamelor-(nortriptyline',
#   'Tylenol',
#   'Lexapro',
#   'depression',
#   'alprazolam',
#   '0.5-mg',
#   'p.o.',
#   'b.i.d.',
#   'Artane',
#   '2-mg',
#   'p.o.',
#   'b.i.d.',
#   'Haldol',
#   '2.5-mg',
#   'p.o.',
#   't.i.d.',
#   'Norvasc',
#   '10-mg',
#   'p.o.',
#   'daily',
#   'nortriptyline',
#   '50-mg',
#   'p.o.',
#   'daily',
#   'Haldol',
#   'anxiety',
#   'CODEINE',
#   'U-tox-positive-for-amphetamines-and-tricyclic-antidepressants',
#   'Acetaminophen',
#   'Haldol',
#   '40',
#   'tablets',
#   'Tylenol',
#   'depression',
#   'AXIS',
#   'Prilosec',
#   '200-mg',
#   'p.o.',
#   'daily',
#   'nortriptyline',
#   '50-mg',
#   'p.o.',
#   'Haldol',
#   '2-mg',
#   'p.o',
#   'Artane',
#   '2-mg',
#   'p.o.',
#   'daily',
#   'Xanax',
#   '0.5-mg',
#   'p.o.',
#   'fexofenadine',
#   '180-mg',
#   'p.o.',
#   'daily',
#   'Flonase',
#   '50-mcg',
#   'two',
#   'sprays',
#   'b.i.d.',
#   'amlodipine',
#   '10-mg',
#   'p.o.',
#   'daily',
#   'lorazepam',
#   '0.5-mg',
#   'p.o.',
#   'q.6',
#   'p.r.n.'],
#  ['daily',
#   '2-mg',
#   'two-sprays-a-day',
#   'Singulair',
#   '10-mg',
#   'once-a-day',
#   'Xyzal',
#   '5-mg',
#   'Spiriva',
#   'once-a-day',
#   'Advair',
#   'twice-a-day',
#   'Prevacid',
#   '30-mg',
#   'twice-a-day',
#   'Os-Cal',
#   '500-mg',
#   'once-a-day',
#   'multivitamin',
#   'once-a-day',
#   'aspirin',
#   '81-mg',
#   'a-day'],
#  ['heparin',
#   'Acute-Stroke-Treatment).Carotid',
#   '4-units',
#   'pRBCs',
#   'Dejerine'],
#  ['ventricular-fibrillation',
#   'epinephrine',
#   'lidocaine',
#   'epinephrine',
#   'lidocaine',
#   'epinephrine',
#   'gorin',
#   'acute-renal-failure',
#   'Nifedipine',
#   'ASA',
#   'Amiodarone',
#   'Capoten',
#   'Isordil',
#   'Tylenol',
#   'Darvocet',
#   'prn',
#   'Reglan',
#   'prn',
#   'Coumadin',
#   'Valium',
#   'prn',
#   'CAD',
#   'SVT'],
#  ['ongoing-pain', 'brachial-plexopathy', 'Guide', 'grade-IV-motor-deficit'],
#  ['Vicodin', 'intracranial-bleed', 'morphine', 'pain-and-his-headache'],
#  ['Vigabatrin',
#   'infantile-spasms',
#   'phenobarbital',
#   'valproic-acid',
#   'Topamax',
#   'Zonegran',
#   'Lamictal',
#   '200-mg',
#   'twice-a-day',
#   '150-mg',
#   'tablet',
#   '25-mg',
#   'tablets',
#   'Zonegran',
#   '25-mg',
#   'daily',
#   'baclofen',
#   '10-mg',
#   'three-times-day',
#   'Xopenex',
#   'Atrovent',
#   'dystonic-cerebral-palsy',
#   'Zonegran',
#   'Lamictal'],
#  ['restless-leg-syndrome',
#   'recurrent-left-lower-extremity-pain',
#   'lumbar-spine-radiograph',
#   'interventional-pain'],
#  ['Lorazepam', 'metoprolol', 'metoprolol'],
#  ['gadolinium', 'Limbic-encephalitis'],
#  ['18-months', 'quivering"-movement-of-his-jaw', 'Tremulous-quivering-of-jaw'],
#  ['Betadine', '1', 'Xylocaine', '-gauge-6-inch-needle', '1-gm'],
#  ['non-small-cell-lung-cancer-of-the-left-upper-lobe', 'lidocaine'],
#  ['sedation',
#   'packed-red-blood-cells',
#   'amoxicillin',
#   'blood-culture',
#   'antibiotics',
#   'antibiotics',
#   'Versed',
#   '1-mg',
#   'sleepy,-the-respiratory-monitors',
#   '20-mcg',
#   'fentanyl'],
#  ['for-approximately-14-to-18-hours',
#   'sleepy',
#   'pressure-in-both-her-legs-and-in-her-thighs',
#   'gabapentin',
#   'to-reduce-the-discomfort',
#   'Gabapentin',
#   '300-mg',
#   'b.i.d.',
#   'multivitamin',
#   'intravenous',
#   'methylprednisolone',
#   'methylprednisolone',
#   'gabapentin',
#   'gabapentin-dose-from',
#   '300-mg',
#   'b.i.d.',
#   'four-times-a-day',
#   '600-mg',
#   'mg',
#   'four-times-a-day'],
#  ['Keppra',
#   '1500',
#   'twice-a-day',
#   'Decadron',
#   '6-mg',
#   'four-times-a-day',
#   'oxycodone',
#   'aspirin',
#   'Prilosec',
#   'Dilantin',
#   '300',
#   'a-day',
#   'Flagyl'],
#  ['fissure/temporal-lobe', 'hemosiderin', 'Dilantin', 'ASA', 'Diltiazem'],
#  [],
#  ['Codeine',
#   'headaches',
#   'Migraine',
#   'Inderal',
#   '40mg',
#   'tab',
#   'b.i.d.',
#   'x-1-week',
#   '1',
#   'tab',
#   'b.i.d.',
#   'x-1-week',
#   '1',
#   'tab',
#   't.i.d.',
#   'stress-in-migraine'],
#  ['slurred-speech'],
#  ['Diabetes-Mellitus-dx', 'gadolinium-contrast'],
#  ['NSAIDs', 'ASA', 'ASA', '325-mg', 'qd'],
#  ['Sulfasalazine',
#   'qid',
#   'Tylenol',
#   '650mg',
#   'q4hours',
#   'non-encapsulated-crytococcus-neoformans',
#   'amphotericin'],
#  ['carpal-tunnel-syndrome',
#   'Prednisone',
#   'Prednisone',
#   'methotrexate',
#   'Cyclosporin',
#   'Imuran',
#   'Cytoxan',
#   'Plaquenil',
#   'Prednisone',
#   '20mg',
#   'qd',
#   'Cytoxan',
#   '75mg',
#   'qd',
#   'Zantac',
#   '150mg',
#   'bid',
#   'Vasotec',
#   '10mg',
#   'bid',
#   'Premarin',
#   '0.625',
#   'qd',
#   'Provera',
#   '2.5mg',
#   'qd',
#   'CaCO',
#   '3-500mg',
#   'bid',
#   'Vit-D',
#   '50,00',
#   '0units',
#   'qweek',
#   'Vit-E',
#   'qd',
#   'MVI',
#   '1',
#   'tab',
#   'qd',
#   'Coumadin',
#   'Dilantin'],
#  [],
#  ['breast-carcinoma', 'pontis', 'brachium-pontis'],
#  ['Decadron',
#   'Phenytoin',
#   '6-beats',
#   'Dilantin',
#   '200mg',
#   'qd',
#   'Decadron',
#   '5mg',
#   'q6',
#   'Carboplatin'],
#  ['ASA',
#   '/-PCN',
#   'rash',
#   'Ticlopidine',
#   '250mg',
#   'bid',
#   'Heparin',
#   'anticoagulation',
#   'Isordil',
#   '20',
#   'tid',
#   'Metoprolol',
#   '25mg',
#   'q12hours',
#   'Ticlid',
#   '250mg',
#   'bid'],
#  ['Compazine', 'One-child', '3-day', 'Florinef', 'seizures'],
#  ['every-day',
#   'heparin',
#   'Prednisone',
#   '80-mg',
#   'qd',
#   'malar-rash',
#   'Depo-Provera',
#   'Prednisone',
#   '80mg',
#   'qd',
#   'Heparin',
#   'anticardiolipin',
#   '5mg',
#   'tid',
#   'heparin',
#   'ASA',
#   '325mg',
#   'bid',
#   'heparin',
#   'heparin',
#   'Solu-Medrol',
#   '125mg',
#   'q12-hours',
#   'ASA',
#   'Warfarin',
#   'Prednisone',
#   '60mg',
#   'qd',
#   'Solu-Medrol',
#   'ASA',
#   '81mg',
#   'qd',
#   'Plaquenil',
#   '200mg',
#   'bid',
#   'Warfarin',
#   'Warfarin'],
#  ['seizure-prophylaxis',
#   'neutropenia',
#   'Depakene',
#   'Tegretol',
#   'BUE',
#   'Tegretol',
#   'Diazepam'],
#  ['10mg',
#   'Decardron',
#   '100gm',
#   'Mannitol',
#   'Medicine',
#   'Bactrim',
#   'DS',
#   'qd',
#   'Diflucan',
#   '100mg',
#   'qd',
#   'Acyclovir',
#   '400mg',
#   'bid',
#   'Xanax',
#   'Stavudine',
#   '40mg',
#   'bid',
#   'Rifabutin',
#   '300mg',
#   'qd',
#   'chronic-diarrhea',
#   'gadolinium-contrast',
#   'Pyrimethamine',
#   '75mg',
#   'qd',
#   'Sulfadiazine',
#   '2-g',
#   'bid'],
#  ['heparin',
#   'peptic-ulcer-disease',
#   'vitamin-B12',
#   'Heparin',
#   'Vitamin-B12',
#   'injection',
#   'q.-week',
#   'Lopressor',
#   'faucet',
#   'drop."',
#   'heparin',
#   'warfarin'],
#  ['slurred-speech',
#   'ASA',
#   'Prednisone',
#   '60mg',
#   'qd',
#   'Tagamet',
#   '400mg',
#   'qhs',
#   'Cytoxan-(',
#   '1,575mg',
#   'Cytoxan',
#   'Cytoxan'],
#  ['Vit-B12',
#   'microglobulin',
#   'slow-slurred-speech',
#   'Decadron',
#   '6mg',
#   'qhours',
#   'Cytoxan',
#   '0.75gm/m2',
#   '1.25gm',
#   'rhythmic-jerking-of-the-LUE',
#   'Dilantin'],
#  ["Parkinson's-Disease",
#   'Sinemet',
#   'Sinemet-CR-2',
#   'TID',
#   'Lopressor',
#   '25mg',
#   'qhs',
#   'Vitamin-E',
#   '1tab',
#   'TID',
#   'Premarin',
#   '1.25mg',
#   'qd',
#   'Synthroid',
#   '0.75mg',
#   'qd',
#   'Oxybutynin',
#   '2.5mg',
#   'isocyamine',
#   '0.125mg',
#   'qd',
#   'Sinemet-CR-2',
#   '1tab-TID',
#   'Sinemet-5-days',
#   'unresponsive-to-Sinemet',
#   'Indomethacin'],
#  ['chemotherapy', 'urinary-retention', 'cisterna-magna'],
#  ['Heparin',
#   'Heparin',
#   'reverse-Trendelenburg-position',
#   'fluids',
#   'sinus-tachycardia-with-rate-dependent-junctional-changes',
#   'esmolol',
#   'labetalol',
#   'ASA',
#   'Procardia-XL',
#   'Labetalol'],
#  [],
#  [],
#  [],
#  [],
#  ['gadolinium'],
#  ['4-month',
#   'develop-numbness-in-the-first',
#   'impaired-sleep',
#   'Naprosyn',
#   'Macrodantin'],
#  ['gadolinium'],
#  [],
#  ['NSAID',
#   'Spine',
#   'Spine',
#   'Coumadin',
#   '4mg',
#   'qd',
#   'Propranolol',
#   'Procardia-XL',
#   'Altace',
#   'Zaroxolyn',
#   'Coumadin',
#   'Lucid',
#   'wheeze'],
#  ['generalized-tonic-clonic-type-seizure',
#   'Iodine',
#   'BCNU',
#   'Procarbazine-chemotherapy-protocols',
#   '5FU',
#   'Carboplatin',
#   '5FU/Carboplatin',
#   'Decadron',
#   '12mg',
#   '/day',
#   'Steroid',
#   'myopathy'],
#  ['Daily-headaches'],
#  ['chronic-back-pain'],
#  [],
#  ['Spine',
#   'Folate',
#   'deep-venous-thrombosis',
#   'heparin',
#   'Coumadin',
#   'Decadron',
#   'Coumadin',
#   '7.5mg',
#   'qd',
#   'Zoloft',
#   '50mg',
#   'qd',
#   'Lithium',
#   '300mg',
#   'bid',
#   'microglobulin',
#   'Decadron',
#   'Cytoxan',
#   'prednisone',
#   'Cytoxan',
#   'Antibiotics',
#   'bacterial-meningitis',
#   'diffuse-leptomeningeal-enhancement-in-both-brain-and-spinal-canal',
#   'Cytoxan',
#   'Imuran',
#   'Imuran',
#   'prednisone',
#   'numerous-deep-venous-thrombosis',
#   'Coumadin'],
#  ['Pitocin',
#   'minor-abdominal-discomfort',
#   'Ibuprofen',
#   'Darvocet',
#   'analgesia',
#   'mild-lumbar-back-pain',
#   'Solu-Cortef',
#   '1000mg',
#   'qd',
#   'PMNS',
#   'Broad-spectrum-antibiotics',
#   'Solu-Medrol',
#   '1g',
#   'qd',
#   'gadolinium-and-was-associated-with-spinal-cord-edema',
#   'one-day',
#   'Praziquantel',
#   '3.6g',
#   '3-doses',
#   'Prednisone',
#   '60-mg',
#   'po',
#   'qd',
#   'antibiotics',
#   'Solu-Medrol',
#   'Prednisone',
#   '60mg',
#   'qd',
#   'Zantac',
#   '50',
#   'qd',
#   'Propulsid',
#   '20mg',
#   'tid',
#   'Enoxaparin',
#   '20mg',
#   'qd',
#   'one-day-course',
#   'Praziquantel',
#   '40mg/kg/day'],
#  ['vitamin',
#   'Coumadin',
#   '2mg',
#   'qd',
#   'Digoxin',
#   '0.25mg',
#   'qd',
#   'Prazosin',
#   '2mg',
#   'qd',
#   'A-Fib',
#   'coumadin',
#   'Peripheral-vascular-disease',
#   'Farmer',
#   'Lucid',
#   'Flaccid-paraplegia-in-BLESensory'],
#  ['generalized-osteoporosis'],
#  ['CAD-with-chronic-CP',
#   'metoprolol',
#   'Benadryl',
#   'ECASA',
#   'Diltiazem',
#   'Isordil',
#   'Enalapril',
#   'Indomethacin',
#   'Terbutaline',
#   'MDI',
#   'Ipratropium-MDI',
#   'Folic-Acid',
#   'Thiamine',
#   'Decadron'],
#  ['One-month', 'tonic-clonic-type-seizures', 'Phenobarbital-prophylaxis'],
#  ['unsteady-on-his-feet',
#   'chronic-low-back-pain',
#   'depression',
#   'Actos',
#   'Ambien',
#   'aspirin',
#   'Coreg',
#   'Entocort',
#   'folic-acid',
#   'Flomax',
#   'iron',
#   'Lexapro',
#   '20-mg',
#   'q.h.s.',
#   'Lipitor',
#   'Pentasa',
#   'Plavix',
#   'Protonix',
#   'Toprol',
#   'Celebrex',
#   'Zetia',
#   "Crohn's-disease",
#   'sleep-apnea',
#   'Deep-Tendon-Reflexes',
#   'depression'],
#  ['generalized-tonic-clonic-seizure',
#   'Lamictal',
#   '2',
#   'Lamictal',
#   'generalized-seizure',
#   'Lamictal',
#   'generalized-tonic-clonic-seizure',
#   'generalized-seizure',
#   'Keppra',
#   'breakthrough-seizure',
#   'Keppra',
#   'Keppra',
#   '500-mg',
#   'b.i.d.'],
#  ['chest-pain', 'Darvocet', 'Flexeril'],
#  ['having-dehydration',
#   'intravenous',
#   'fluids',
#   'Effexor',
#   '25-mg',
#   'trazodone',
#   '100-mg',
#   'severe-sleep-maintenance-insomnia',
#   'Korea',
#   'DHEA-sulfate',
#   'Remeron',
#   '15-mg',
#   'h.s.'],
#  ['Lipitor',
#   'Lipitor',
#   'Zetia',
#   'diabetes-based',
#   'amlodipine',
#   'Diovan',
#   'Zetia',
#   'hydrochlorothiazide',
#   'Lovaza-(fish-oil)',
#   'Niaspan',
#   'aspirin',
#   'Chantix',
#   'Deep-Tendon-Reflexes'],
#  ['chemotherapy',
#   'chemotherapy',
#   'carboplatin',
#   'cyclophosphamide',
#   'doxorubicin',
#   'chemotherapy',
#   'nasal-congestion',
#   'fluconazole',
#   'Bactrim',
#   '32-mg',
#   'by-mouth',
#   'twice-a-day-on-Friday,-Saturday',
#   'daily',
#   'Fluconazole',
#   '3',
#   'Zofran',
#   '1.5-mg',
#   'every-6-hours-as-needed',
#   'nausea',
#   'chemotherapy',
#   'Bactrim',
#   'twice-a-day',
#   'fluconazole',
#   'fluconazole',
#   'chemotherapy',
#   'carboplatin',
#   'cyclophosphamide',
#   'doxorubicin',
#   'prior-history-of-neutropenia',
#   'chemotherapy',
#   'chemotherapy',
#   'fluconazole',
#   'recent-history-of-thrush'],
#  ['sedation',
#   'Diastat',
#   '3-mL',
#   'b.i.d',
#   'mg',
#   'b.i.d.',
#   'lorazepam',
#   '1-mg',
#   'p.r.n.',
#   'acetaminophen',
#   'azithromycin',
#   'jerky-limb-movements'],
#  ['Copaxone', 'Copaxone', 'Copaxone', 'every-other-day'],
#  ['statin',
#   'statin',
#   'brush-his-teeth',
#   'Prozac',
#   'Metformin',
#   '500-mg',
#   'three-times-a-day',
#   'Lipitor',
#   '10-mg',
#   'lisinopril',
#   '20-mg',
#   'per-day',
#   'metoprolol',
#   '50-mg',
#   'Uroxatral',
#   '10-mg',
#   'Detrol-LA',
#   '4-mg',
#   'aspirin',
#   '81-mg',
#   'spinal-catheter-protocol',
#   'spinal-catheter-protocol',
#   'infection-associated-with-the-spinal-catheter-protocol'],
#  ['seizure-medication',
#   'seizure',
#   'breakthrough-seizure',
#   'Diastat',
#   'convulsive-seizure',
#   '20-mg',
#   'generalized-tonic-clonic-seizures',
#   '1.5-mg',
#   'lorazepam-x',
#   'fosphenytoin',
#   '15',
#   'generalized-tonic-seizure',
#   'Keppra',
#   'Lamictal',
#   'allergic-reaction',
#   'rash',
#   'hypotension',
#   'valproic-acid',
#   'Tranxene',
#   'taper',
#   'Topamax',
#   'Include-Diastat',
#   '20-mg',
#   'Topamax',
#   '25-mg',
#   'b.i.d',
#   'Tranxene',
#   '15-mg',
#   'b.i.d.',
#   'Depakote',
#   '125-mg',
#   't.i.d',
#   'Depacon',
#   '250-mg',
#   'Topamax',
#   'Tranxene',
#   'Topamax',
#   '25-mg',
#   '50-mg',
#   'at-night'],
#  ['gabapentin',
#   'pain-control',
#   'insulin',
#   'diabetes',
#   'Trazodone',
#   'simvastatin',
#   'hydrochlorothiazide',
#   'Prevacid',
#   'lisinopril',
#   'glipizide',
#   'gabapentin',
#   'insulin',
#   'Neurontin',
#   'oxycodone',
#   '30-mg',
#   'q.d.',
#   'for-five-days',
#   '60-mg',
#   'q.d'],
#  ['problems-with-blood-pressure-drops',
#   'antibiotics',
#   'urinary-retention',
#   'Fludrocortisone',
#   '0.1-mg',
#   'p.o.',
#   'q.d.',
#   'midodrine',
#   '5-mg',
#   'p.o.',
#   'q.i.d.',
#   'Cymbalta',
#   '30-mg',
#   'p.o.',
#   'Prilosec',
#   '20-mg',
#   'p.o',
#   'Lortab',
#   '10-mg',
#   'p.o.',
#   'Amoxil',
#   '500-mg',
#   'p.o',
#   'vitamin-D-10',
#   '00-units',
#   'per-day',
#   'Metamucil-p.r.n.,-enteric',
#   'aspirin',
#   'once-a-day',
#   'Colace',
#   '200-mg',
#   'p.o.',
#   'q.d.',
#   'Senokot',
#   'three',
#   'tablets',
#   'p.o.',
#   'p.r.n.',
#   'Reglan',
#   '10-mg',
#   'p.o.',
#   'q.6',
#   'Xanax',
#   '0.25-mg',
#   'p.o.',
#   'q.8',
#   'p.r.n.',
#   'Ambien',
#   '5-mg',
#   'p.o.',
#   'q.h.s.-p.r.n.',
#   'Dilaudid',
#   '2-mg',
#   'tablets',
#   'p.o.',
#   'p.r.n.',
#   'Protonix',
#   '40-mg',
#   'Megace',
#   '400',
#   'Vitamin-B',
#   'rheumatoid-arthritis',
#   'cryoglobulins',
#   'midodrine',
#   '2.5-mg',
#   'three-times-a-day-as-needed',
#   '5-mg',
#   'four-times-a-day',
#   '2.5',
#   'three-times-a-day',
#   '5-mg',
#   'three-times-a-day.'],
#  ['GAIT'],
#  ['Tylenol', '650', 'p.o.', 'q.6', 'p.r.n.', 'headache'],
#  ['Clozaril',
#   'Risperdal',
#   'lithium',
#   'Clozaril',
#   '1200-mg',
#   'Risperdal',
#   'lithium',
#   'Clozaril',
#   'anti-psychotics',
#   'psychotic-bout',
#   'diabetes-mellitus',
#   'Zyprexa',
#   'AXIS',
#   'benzodiazepines'],
#  ['relieve-the-pain',
#   'five-to-six-minutes',
#   'insomnia',
#   'bipolar-disorder',
#   'Ativan',
#   'Imitrex',
#   'Levoxyl',
#   'albuterol',
#   'metered-dose',
#   'inhaler',
#   'as-needed',
#   'Zofran',
#   'bipolar-disorder',
#   'Intelligence-(WASI)',
#   'bipolar-disorder'],
#  ['back-pain',
#   'Percocet',
#   'daily',
#   'Celebrex',
#   '200-mg',
#   'levothyroxine',
#   '0.025-mg',
#   'Vytorin',
#   '10/40-mg',
#   'lisinopril',
#   '10-mg',
#   'Coreg',
#   '10-mg',
#   'glucosamine',
#   'chondroitin',
#   'aspirin',
#   '81-mg',
#   'Lipitor',
#   '40-mg',
#   'levothyroxine',
#   'two-days',
#   'carcinoma',
#   'seizure-disorder',
#   'TowerWisconsin-Card',
#   'State'],
#  ['amitriptyline',
#   'prophylactic-treatment',
#   'Motrin',
#   'abortive-treatment.2',
#   'papaverine',
#   'headaches',
#   'papaverine',
#   'lisinopril',
#   'glipizide',
#   'metformin,-vitamin-D',
#   'Centrum-multivitamin',
#   'tablets',
#   'Actos',
#   'lorazepam',
#   'as-needed',
#   'Vytorin',
#   'Celexa',
#   'pain',
#   'foods-times,-which-worsen-migraine',
#   '10-mg',
#   'Motrin',
#   '800-mg',
#   'as-needed',
#   'severe-headaches',
#   'reduce-migraine-symptoms'],
#  ['Keppra',
#   'oral',
#   'solution',
#   '0-mg',
#   'b.i.d.',
#   'help-prevent-febrile-seizures',
#   'febrile-seizure',
#   'Keppra',
#   'febrile-seizures',
#   'generalized-seizures',
#   'sedation',
#   'Keppra',
#   '300-mg',
#   'p.o.',
#   'b.i.d.',
#   'daily'],
#  [],
#  ['Organic-brain-syndrome',
#   'multiple-myeloma',
#   'multiple-myeloma',
#   'CODEINE',
#   'oxygen',
#   'lepto',
#   'hyperviscosity-syndrome-or-provoked-seizure',
#   'aspirin'],
#  ['minor-procedure-area',
#   'chlorhexidine',
#   'phenol',
#   'injections-in-this-area-injections',
#   'phenol',
#   '5-mL',
#   'phenol',
#   'phenol',
#   '150-units',
#   '1-mL'],
#  ['botulinum-toxin',
#   'injection',
#   'minor-procedure-area',
#   'chlorhexidine',
#   '6-mL',
#   'phenol',
#   'phenol-injections',
#   'phenol',
#   '100-units',
#   '1-mL'],
#  ['chlorhexidine',
#   '4-mL',
#   'phenol',
#   'Phenol',
#   'injections',
#   'phenol',
#   '50-units',
#   '1-mL'],
#  ['brain-tumor-removal',
#   'DVT-in-the-left-calf',
#   'Coumadin',
#   'Keppra',
#   'Decadron',
#   'two-times'],
#  ['aspiration-and-infusion',
#   'anesthesia',
#   'usual-sterile-manner',
#   'nostril',
#   'arachnoid',
#   'Bacitracin'],
#  ['Imitrex', 'Motrin', '800-mg', 'twice-a-day'],
#  [],
#  ['for-his-pain-management',
#   'reduce-his-pain',
#   'oxygen',
#   'oxygen',
#   'methadone',
#   'tablets',
#   'four-times-a-day',
#   'morphine',
#   'mg',
#   'three-times-a-day',
#   'Dilaudid',
#   'two',
#   'tablets',
#   'by-mouth',
#   'every-two-hours',
#   'reduce-his-pain',
#   'Neurontin',
#   '1600-mg',
#   'three-times-a-day',
#   'Effexor-XR',
#   '250-mg',
#   'once-a-day',
#   'Cytomel',
#   '25-mcg',
#   'once-a-day',
#   'Seroquel',
#   '100-mg',
#   'p.o.',
#   'q.-day',
#   'levothyroxine',
#   '300-mcg',
#   'p.o.',
#   'q.-day',
#   'Prinivil',
#   '20-mg',
#   'p.o.',
#   'q.-day',
#   'Mevacor',
#   '40-mg',
#   'p.o.',
#   'q-day',
#   'unfortunate-situation'],
#  ['generalized-tonic-clonic-seizures',
#   'Tegretol',
#   'toxicity-(hallucinations',
#   'Trileptal',
#   'Trileptal',
#   '300-mg',
#   'twice-a-day',
#   'electroencephalogram-in-the-near-future'],
#  ['steroid', 'injections'],
#  ['local-ER',
#   'valium',
#   '5-mg',
#   '1.0g.',
#   'seizures',
#   'Librium',
#   'taper',
#   'possible-alcoholic-withdrawal'],
#  ['Betadine',
#   'Vicryl',
#   'saline',
#   'saline',
#   'Vicryl',
#   'saline',
#   'Vicryl',
#   'skin-was-closed-with-skin-staples'],
#  ['obstructive-sleep-apnea',
#   'six-and-a-half-hours',
#   'sleepy-in-the-morning',
#   'chronic-hypertension'],
#  ['pain-control',
#   'hydrocodone',
#   '10/325-mg',
#   'every-6-hours',
#   'Flexeril',
#   '10-mg',
#   'p.o.',
#   'at-bedtime',
#   'Xanax',
#   '0.25-mg',
#   'p.o.',
#   '4-times-a-day',
#   'Neurontin',
#   '200-mg',
#   '3-times-a-day',
#   'propranolol',
#   '10-mg',
#   'twice-a-day',
#   'oxybutynin',
#   '5-mg',
#   'p.o.',
#   'twice-a-day',
#   'Namenda',
#   '10-mg',
#   'p.o.',
#   'daily',
#   'Aricept',
#   '10-mg',
#   'p.o.',
#   'daily',
#   'degenerative-joint-disease',
#   "the-patient's-low-blood-pressure-and-heart-rate-low",
#   'fluid',
#   'normal-saline',
#   'Protonix',
#   '40-mg',
#   'Aricept',
#   'Flexeril',
#   'gabapentin',
#   'pain-control',
#   'Percocet',
#   'morphine-sulfate',
#   'as-needed',
#   'calcium-with-vitamin-D'],
#  ['Anapro', 'for-two-weeks'],
#  ['high-grade-glioma', 'chemotherapy', 'chemotherapy'],
#  ['cerebral-palsy',
#   'Trileptal',
#   'failure-to-prevent-his-seizures',
#   'Topamax',
#   '25-mg',
#   'seizure',
#   'Diastat',
#   '7.5-mg',
#   'lorazepam',
#   '2-mg',
#   'Topamax',
#   '50-mg',
#   'twice-a-day',
#   '75-mg',
#   'at-night',
#   'for-2-weeks',
#   '75-mg',
#   'twice-daily',
#   'Topama',
#   'Topama',
#   'Keppra',
#   'Zonegran',
#   'Lamictal'],
#  ['anesthesia',
#   'chlorhexidine',
#   'microscissors',
#   'Cavitron',
#   'used-to-free-up-the-tumor',
#   'Cavitron',
#   'Cavitron',
#   'Duragen',
#   'Vicryls',
#   'Vicryl'],
#  ['suspected-seizure-activity',
#   'Dilantin',
#   '300-mg',
#   'daily',
#   'Dilantin',
#   'Dilantin',
#   'Dilantin'],
#  ['Local-anesthesia',
#   '1',
#   'Xylocaine',
#   'epinephrine',
#   '1',
#   'Xylocaine',
#   'infiltration'],
#  ['temporal-arteritis',
#   'temporal-arteritis',
#   'Xylocaine',
#   '1',
#   'Monocryl',
#   'Xylocaine',
#   'Monocryl'],
#  ['Advil', 'Motrin', 'Tylenol'],
#  ['Lanoxin',
#   'amoxicillin',
#   'Hydergine',
#   'Cardizem',
#   'Lasix',
#   'Micro',
#   'chronic-atrial-fibrillation',
#   'Coumadin-anticoagulation'],
#  ['had-bilateral-knee-replacement',
#   'Plavix',
#   'aspirin',
#   '81-mg',
#   'Proscar',
#   '5-mg',
#   'q.d-and-Synthroid',
#   'mg',
#   'q.d',
#   'cholesterol-and-stroke-for-risk-factors'],
#  ['Six-cm', 'Marcaine', 'epinephrine'],
#  ['antibiotics', 'hemostasis', 'Vicryl', 'Ace-bandages'],
#  ['intracranial-pressure', 'FFP', 'vitamin-K'],
#  ['seizures'],
#  ['seizures'],
#  [],
#  [],
#  ['penicillamine',
#   'shortness-of-breath',
#   'atrial-fibrillation-with-rapid-rate.',
#   'Lopressor',
#   'Coumadin',
#   'aspirin',
#   '325-mg',
#   'once-a-day',
#   'penicillamine',
#   'metoprolol',
#   'aspirin',
#   'Coumadin',
#   'penicillamine',
#   '250-mg',
#   'p.o.',
#   'four-times-a-day',
#   'metoprolol',
#   '12.5-mg',
#   'twice-a-day',
#   'aspirin',
#   '325-mg',
#   'a-day']]

# %% [markdown]
# ## Machine learning with bag of words

# %%
# add a new column bow to the data
dat["bow"] = bows
bow_df = dat[["sample_type", "bow"]]
bow_df
# Out:
#                sample_type                                                bow
# 0     Allergy / Immunology  [Claritin, Zyrtec, Zyrtec, loratadine, Nasonex...
# 1     Allergy / Immunology  [perioral-swelling, allergy-reaction, Keflex, ...
# 2     Allergy / Immunology  [prednisone, antibiotic, Advair, Nasonex, Xope...
# 3     Allergy / Immunology  [chronic-sinusitis, antibiotics, Veramyst, nas...
# 4     Allergy / Immunology                             [peptic-ulcer-disease]
# ...                    ...                                                ...
# 4994               Urology                                 [local-anesthesia]
# 4995               Urology                                           [Vicryl]
# 4996               Urology    [lidocaine, anesthesia, Tylenol, Codeine, pain]
# 4997               Urology  [Betadine, 2, Xylocaine, 2, Xylocaine, Bacitra...
# 4998               Urology  [intravenous, urinary-retention, urinary-reten...
#
# [4999 rows x 2 columns]
