# %%
from medacy.model.model import Model
import pandas as pd
from tqdm import tqdm
import json

# %%
model = Model.load_external('medacy_model_clinical_notes')

# %%
dat = pd.read_csv("../mtsample_scraped.csv")
notes = list(dat.medical_transcription)
nn = notes[0:10]

# %%
bows = []
for note in nn:
    annotation = model.predict(note)
    bow = [ann[3].replace(" ", "-") for ann in list(annotation)]
    bows.append(bow)
bows
# Out:
# [['Claritin',
#   'Zyrtec',
#   'Zyrtec',
#   'loratadine',
#   'Nasonex',
#   'two-sprays',
#   'in-each-nostril',
#   'for-three-weeks'],
#  ['perioral-swelling',
#   'allergy-reaction',
#   'Keflex',
#   'skin-cellulitis-dialysis-shunt-infection',
#   'atenolol',
#   'blood-pressure-control',
#   'corticosteroid',
#   'antihistamine',
#   'Atenolol',
#   'sodium-bicarbonate',
#   'Heparin',
#   'Acute-allergic-reaction',
#   'the-sensitivity-scale',
#   'cephalosporin-antibiotics',
#   'allergic-reaction',
#   'atenolol',
#   'allergic-reactions',
#   'impending-allergic-reaction',
#   'EpiPen'],
#  ['prednisone',
#   'antibiotic',
#   'Advair',
#   'Nasonex',
#   'Xopenex',
#   'Zicam',
#   'Zithromax',
#   'prednisone',
#   'albuterol',
#   'foreign-body-pneumonia',
#   'high-dose',
#   'albuterol',
#   'Decadron',
#   'by-mouth'],
#  ['chronic-sinusitis',
#   'antibiotics',
#   'Veramyst',
#   'nasal',
#   'spray',
#   'two-sprays',
#   'each-nostril',
#   'daily',
#   'nasal-saline',
#   'daily',
#   'Clarinex',
#   '5-mg',
#   'daily'],
#  ['peptic-ulcer-disease'],
#  ['Allegra',
#   'daily',
#   'Advair',
#   'vaginal-irritation',
#   'urinary-tract-infection',
#   'Proventil',
#   'Sulfa',
#   'Proventil',
#   'daily',
#   'Flovent',
#   '44-mcg',
#   'two',
#   'puffs',
#   'p.o.',
#   'b.i.d.',
#   'Advair',
#   'shortness-of-breath-worsens',
#   'Allegra',
#   'Flonase',
#   'daily',
#   'fluoxetine',
#   '20-mg',
#   'one',
#   'tablet',
#   'p.o.',
#   'calcium',
#   '400',
#   'vitamin-D'],
#  ['rash',
#   'high-dose',
#   'aspirin',
#   'IVIG',
#   'IVIG',
#   'Aspirin',
#   'high-dose-340',
#   'mg',
#   'q.6',
#   'for-1-day',
#   'aspirin',
#   'low-dose-40-mg',
#   'q.d.',
#   'for-14-days',
#   'prevent-his-GI',
#   'aspirin',
#   '15-mg',
#   'p.o.',
#   'once-a-day',
#   'vaccine'],
#  ['Coli-K1', 'Samples-of-Blood-(type-O+', 'Homicide'],
#  ['right-breast-quadrant',
#   '550-grams-and-500-grams',
#   '.Trichloroethanol',
#   'Diphenhydramine',
#   'Bendaryl',
#   'Clonazepam-(Klonopin',
#   ')-0.0',
#   '4-mg',
#   'Diazepam',
#   'Valium',
#   ')-0.',
#   'Nordiazepam',
#   '(metabolite)-0.',
#   'Temazepam',
#   '(metabolite)-0.09-mg',
#   'Oxazepam',
#   '0.0',
#   'Lorazepam',
#   '22.0',
#   'atropine',
#   'topiramate',
#   'ciprofloxacin',
#   'acetaminophen',
#   ').II.',
#   'GASTROENTERITIS'],
#  ['one',
#   'affix',
#   'Coli-K1',
#   'dl,-Blood-(Heart)Ethanol',
#   'One',
#   'One-(1)',
#   'Fifteen-(15)',
#   'swabs']]

# %%
def get_bows(notes):
    # notes: medical notes as a list of strings
    bows = []
    for note in tqdm(notes):
        annotation = model.predict(note)
        bow = [ann[3].replace(" ", "-") for ann in list(annotation)]
        bows.append(bow)
    return(bows)

# %%
bows = get_bows(notes)
# Out:
# 100%|██████████| 4999/4999 [13:24<00:00,  6.21it/s]

# %%
# save bows which take 13 min to run
with open("bows_medacy.txt", "w") as f:
    json.dump(bows, f)
    
with open("bows_medacy.txt", "r") as f:
    if "bows" not in globals():
        bows = json.load(f)

# %%
# add a new column bow to the data
dat["bow"] = bows
bow_df = dat[["sample_type", "bow"]]
bow_df
# Out:
#                sample_type                                                bow
# 0     Allergy / Immunology  [Claritin, Zyrtec, Zyrtec, loratadine, Nasonex...
# 1     Allergy / Immunology  [perioral-swelling, allergy-reaction, Keflex, ...
# 2     Allergy / Immunology  [prednisone, antibiotic, Advair, Nasonex, Xope...
# 3     Allergy / Immunology  [chronic-sinusitis, antibiotics, Veramyst, nas...
# 4     Allergy / Immunology                             [peptic-ulcer-disease]
# ...                    ...                                                ...
# 4994               Urology                                 [local-anesthesia]
# 4995               Urology                                           [Vicryl]
# 4996               Urology    [lidocaine, anesthesia, Tylenol, Codeine, pain]
# 4997               Urology  [Betadine, 2, Xylocaine, 2, Xylocaine, Bacitra...
# 4998               Urology  [intravenous, urinary-retention, urinary-reten...
#
# [4999 rows x 2 columns]
