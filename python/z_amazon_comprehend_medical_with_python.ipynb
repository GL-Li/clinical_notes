# %% [markdown]
# # AWS Comprenend Medical with Python
#
# **Very important**:
#
# - Do not run the cells. It costs money and may overwrite saved data.
# - Comprehend Medical only accept note string shorter than 20000 charaters. When preparing a dataframe `df` with notes column `note`, filter off those longer notes with:
# `df = df[df.note.str.len() < 20000]`
#
# - Comprehend medical is very expensive. The cost for one entity is  \\$0.01. On aveage, there is one entity in 100 characters. So the cost of 1 M character is about $100.

# %% [markdown]
# ### Tutorial
# https://docs.aws.amazon.com/comprehend/latest/dg/get-started-api-med.html
#
# #### boto3 documentation
# https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/comprehendmedical.html

# %% [markdown]
# ## A quick example
# Comprehend Medical returns a dictionary of medical entities and other metadata regarding to the request sent to Amazon. Only the medical entities are useful for text analysis.

# %%
import boto3
client = boto3.client(service_name='comprehendmedical', region_name='us-east-1')
result = client.detect_entities_v2(Text= 'cerealx 84 mg daily')

# %%
result['Entities']
# Out:
# [{'Id': 0,
#   'BeginOffset': 0,
#   'EndOffset': 7,
#   'Score': 0.8877691626548767,
#   'Text': 'cerealx',
#   'Category': 'MEDICATION',
#   'Type': 'BRAND_NAME',
#   'Traits': [],
#   'Attributes': [{'Type': 'DOSAGE',
#     'Score': 0.9337134957313538,
#     'RelationshipScore': 0.9995118379592896,
#     'Id': 1,
#     'BeginOffset': 8,
#     'EndOffset': 13,
#     'Text': '84 mg',
#     'Traits': []},
#    {'Type': 'FREQUENCY',
#     'Score': 0.990627646446228,
#     'RelationshipScore': 0.9987651109695435,
#     'Id': 2,
#     'BeginOffset': 14,
#     'EndOffset': 19,
#     'Text': 'daily',
#     'Traits': []}]}]

# %% [markdown]
# ## Example with one medical note
# We will extract medical entities from the first note in mtsample dataset.

# %%
note = "SUBJECTIVE: This 23-year-old white female presents with complaint of allergies. She used to have allergies when she lived in Seattle but she thinks they are worse here. In the past, she has tried Claritin, and Zyrtec. Both worked for short time but then seemed to lose effectiveness. She has used Allegra also. She used that last summer and she began using it again two weeks ago. It does not appear to be working very well. She has used over-the-counter sprays but no prescription nasal sprays. She does have asthma but doest not require daily medication for this and does not think it is flaring up.MEDICATIONS: Her only medication currently is Ortho Tri-Cyclen and the Allegra.ALLERGIES: She has no known medicine allergies.OBJECTIVE:Vitals: Weight was 130 pounds and blood pressure 124/78.HEENT: Her throat was mildly erythematous without exudate. Nasal mucosa was erythematous and swollen. Only clear drainage was seen. TMs were clear.Neck: Supple without adenopathy.Lungs: Clear.ASSESSMENT: Allergic rhinitis.PLAN:1. She will try Zyrtec instead of Allegra again. Another option will be to use loratadine. She does not think she has prescription coverage so that might be cheaper.2. Samples of Nasonex two sprays in each nostril given for three weeks. A prescription was written as well."
mt = client.detect_entities_v2(Text = note)

# %% [markdown]
# ### get bog of words from medical entities of one medical note

# %%
def get_bow(me):
    # me: medical entities extracted from Amazon Comprehend Medical aaa["Entities"]
    text = [dic["Text"] for dic in me]
    traits = [dic["Traits"] for dic in me]  # trait including negation
    
    negation = []
    for ele in traits:
        if len(ele) == 0:
            negation.append("")
        elif len(ele) != 0:
            count = 0
            for dic in ele:
                if dic["Name"] == "NEGATION":
                    count += 1
            if count == 0:
                negation.append("")
            else:
                negation.append("-1")
    
    # attache "-1" to the text if it is negative
    bow = [t.replace(" ", "-") + n for t, n in zip(text, negation)]
    
    return(bow)

# %%
print(get_bow(mt["Entities"]))
# Out:
# ['23', 'allergies', 'Seattle', 'Claritin', 'Zyrtec', 'lose-effectiveness', 'Allegra', 'summer', 'asthma', 'Ortho-Tri-Cyclen', 'Allegra', 'Vitals', 'Weight', 'blood-pressure', 'HEENT', 'throat', 'erythematous', 'exudate-1', 'Nasal-mucosa', 'erythematous', 'swollen', 'clear-drainage', 'TMs', 'TMs-were-clear', 'Neck', 'Supple', 'adenopathy-1', 'Lungs', 'Lungs:-Clear', 'Allergic-rhinitis', 'Zyrtec', 'Allegra', 'loratadine', 'Nasonex']

# %% [markdown]
# ## Try 10 mtsample motes
# Alway considering cost when using Comprehend Medical.

# %%
import pandas as pd
import json
#dat = pd.read_csv("../mtsample_scraped.csv")

# %%
notes = list(dat.medical_transcription)
nn = notes[0:10]

# %%
# do not run this cell, save money
mes = []
for nt in nn:
    me = client.detect_entities_v2(Text = nt)
    me = me["Entities"]
    mes.append(me)

# %%
# save the entities, it cost real money
import json
with open("comprehend_first_10_cases.txt", "w") as f:
    json.dump(mes, f)

# %%
# read the saved file
with open("comprehend_first_10_cases.txt", "r") as f:
    try_10 = json.load(f)

# %%
# get the bag of words
bows =[]
for me in try_10:
    bows.append(get_bow(me))

print(bows[0:2])
# Out:
# [['23', 'allergies', 'Seattle', 'Claritin', 'Zyrtec', 'lose-effectiveness', 'Allegra', 'summer', 'asthma', 'Ortho-Tri-Cyclen', 'Allegra', 'Vitals', 'Weight', 'blood-pressure', 'HEENT', 'throat', 'erythematous', 'exudate-1', 'Nasal-mucosa', 'erythematous', 'swollen', 'clear-drainage', 'TMs', 'TMs-were-clear', 'Neck', 'Supple', 'adenopathy-1', 'Lungs', 'Lungs:-Clear', 'Allergic-rhinitis', 'Zyrtec', 'Allegra', 'loratadine', 'Nasonex'], ['34', 'recommendation-of-Emergency-Room', 'medical-records', 'allergic-reaction', 'ABC-Medical-Center', 'perioral-swelling', '05/03/2008', 'ABC-Medical-Center', 'XYZ-Medical-Center', 'renal-failure', 'dialysis', 'allergy-reaction', 'Keflex-1', 'skin', 'skin-cellulitis', 'shunt-infection', 'anaphylactic-1', 'angioedema-reactions-1', 'atenolol', 'blood-pressure-control', 'corticosteroid', 'corticosteroid-therapy', 'antihistamine', 'antihistamine-therapy', 'urticaria', 'renal-failure', 'hypertension', 'renal-failure', 'dialysis', 'hypertension', 'PermCath-insertion', 'peritoneal-dialysis', 'heart', 'heart-disease', 'carcinoma', 'food-allergies', 'hypertension', 'Atenolol', 'sodium-bicarbonate', 'Lovaza', 'Dialyvite', 'Heparin-1', 'thrombocytopenia', 'PHYSICAL-EXAMINATION', 'VITAL-SIGNS', 'Age', 'blood-pressure', 'pulse', 'temperature', 'weight', 'height', 'feet', 'GENERAL', 'healthy-appearing', 'alert-and-oriented-to-person,-place-and-time', 'responds-appropriately', 'distress-1', 'HEAD', 'Normocephalic', 'masses-1', 'lesions-1', 'FACE', 'facial-tenderness-1', 'asymmetry-1', 'EYES', 'Pupils', 'equal', 'round', 'reactive-to-light-and-accommodation', 'Extraocular-movements-are-intact', 'EARS', 'tympanic-membranes', 'tympanic-membranes-are-intact', 'good-light-reflex', 'external-auditory-canals-are-clear', 'auditory-canals', 'lesions-1', 'masses-1', 'Rinne-tests', 'NOSE', 'nasal-cavities', 'nasal-cavities-are-patent', 'nasal-septum', 'nasal-septum-is-midline', 'nasal-discharges-1', 'masses-1', 'lesions-1', 'THROAT', 'oral-mucosa', 'oral-mucosa-appears-healthy', 'Dental-hygiene-is-maintained-well', 'oropharyngeal-masses-1', 'lesions-1', 'postnasal-drip-1', 'NECK', 'neck', 'neck-is-supple', 'adenopathy-1', 'masses-1', 'trachea', 'trachea-is-midline', 'thyroid-gland', 'thyroid-gland-is-of-normal-size', 'nodules-1', 'NEUROLOGIC', 'Facial-nerve', 'Facial-nerve-is-intact', 'cranial-nerves', 'cranial-nerves-are-intact', 'focal-deficit-1', 'LUNGS', 'Clear-to-auscultation', 'wheeze-1', 'HEART', 'Regular-rate-and-rhythm', 'murmur-1', 'allergic-reaction', 'Keflex', 'Renal-failure', 'dialysis', 'Hypertension', 'RAST-allergy-testing', 'cephalosporin-1', 'cephalosporin-antibiotics', 'antibiotics-1', 'allergic-reaction', 'atenolol', 'anaphylaxis', 'allergic-reactions', 'EpiPen-1', 'angioedema', 'allergic-reaction', 'sensation-of-impending-allergic-reaction', 'emergency-room', 'EpiPen']]

# %% [markdown]
# ## Download comprehend medical data for Gastroenterology and neurology cases
# Start from very beginning.

# %%
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
dat = pd.read_csv("../mtsample_scraped.csv")

# %%
# save the selected data for future reproducible work
dat_gas_neu = dat.query('sample_type in ["Gastroenterology", "Neurology"]')
dat_gas_neu = dat_gas_neu[dat_gas_neu.medical_transcription.str.len() < 20000] # remove notes longer than 2000
dat_gas_neu["id"] = range(1, dat_gas_neu.shape[0] + 1)
selected = dat_gas_neu[["id", "sample_type", "medical_transcription"]]
selected.columns = ["id", "sample_type", "medical_note"]
selected.to_csv("mtsample_gastroenterology_neurology.csv", index=False)

# %%
selected
# Out:
#        id       sample_type                                       medical_note
# 1328    1  Gastroenterology  PREOPERATIVE DIAGNOSIS: Abdominal wall abscess...
# 1329    2  Gastroenterology  PREOPERATIVE DIAGNOSES: 1. Congenital chylous ...
# 1330    3  Gastroenterology  CHIEF COMPLAINT: Abdominal pain.HISTORY OF PRE...
# 1331    4  Gastroenterology  PREOPERATIVE DIAGNOSIS: Recurrent re-infected ...
# 1332    5  Gastroenterology  CHIEF COMPLAINT: Nausea.PRESENT ILLNESS: The p...
# ...   ...               ...                                                ...
# 2259  447         Neurology  TIME SEEN: 0734 hours and 1034 hours.TOTAL REC...
# 2260  448         Neurology  DATE OF EXAMINATION: Start: 12/29/2008 at 1859...
# 2261  449         Neurology  EEG during wakefulness demonstrates background...
# 2262  450         Neurology  PROCEDURE: EEG during wakefulness demonstrates...
# 2263  451         Neurology  Doctor's NameDoctor's AddressDear Doctor:This ...
#
# [451 rows x 3 columns]

# %%
dat_gas_neu = pd.read_csv("mtsample_gastroenterology_neurology.csv")
gas_neu_notes = list(dat_gas_neu.medical_note)
dat_gas_neu.shape
# Out:
# (451, 6)

# %%
# Do not run, very expensive
# download and save result
mes = []
for nt in tqdm(gas_neu_notes):
    me = client.detect_entities_v2(Text = nt)
    me = me["Entities"]
    mes.append(me)

# %%
# save the entities, it cost real money
import json
with open("comprehend_medical_neurology_gastroenterology.txt", "w") as f:
    json.dump(mes, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b24349d6810f> in <module>
#       2 import json
#       3 with open("comprehend_medical_neurology_gastroenterology.txt", "w") as f:
# ----> 4     json.dump(mes, f)
#
# NameError: name 'mes' is not defined

# %%
# load comprehend_medical
with open("comprehend_medical_neurology_gastroenterology.txt", "r") as f:
    mes = json.load(f)
len(mes)
# Out:
# 451

# %%
bows =[]
for me in mes:
    bows.append(" ".join(get_bow(me)))
    
bows_amazon_gas_neu = pd.DataFrame({
    "id" : range(1, len(bows) + 1),
    "amazon_me" : bows
})

bows_amazon_gas_neu.to_csv("amazon_medical_entities.csv", index=False)

# %%
mes[0]
# Out:
# [{'Id': 46,
#   'BeginOffset': 24,
#   'EndOffset': 38,
#   'Score': 0.9543163776397705,
#   'Text': 'Abdominal wall',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 24,
#   'BeginOffset': 24,
#   'EndOffset': 46,
#   'Score': 0.9218462109565735,
#   'Text': 'Abdominal wall abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9622772932052612}]},
#  {'Id': 47,
#   'BeginOffset': 72,
#   'EndOffset': 86,
#   'Score': 0.9800175428390503,
#   'Text': 'Abdominal wall',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 25,
#   'BeginOffset': 72,
#   'EndOffset': 94,
#   'Score': 0.9249770641326904,
#   'Text': 'Abdominal wall abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.9425454139709473}]},
#  {'Id': 26,
#   'BeginOffset': 106,
#   'EndOffset': 114,
#   'Score': 0.29718276858329773,
#   'Text': 'Incision',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': []},
#  {'Id': 0,
#   'BeginOffset': 106,
#   'EndOffset': 127,
#   'Score': 0.7004805207252502,
#   'Text': 'Incision and drainage',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 27,
#   'BeginOffset': 119,
#   'EndOffset': 127,
#   'Score': 0.7578290700912476,
#   'Text': 'drainage',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': []},
#  {'Id': 1,
#   'BeginOffset': 129,
#   'EndOffset': 132,
#   'Score': 0.8345500826835632,
#   'Text': 'I&D',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 28,
#   'BeginOffset': 137,
#   'EndOffset': 154,
#   'Score': 0.885458767414093,
#   'Text': 'abdominal abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8984646797180176}]},
#  {'Id': 2,
#   'BeginOffset': 156,
#   'EndOffset': 178,
#   'Score': 0.9725889563560486,
#   'Text': 'excisional debridement',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 48,
#   'BeginOffset': 203,
#   'EndOffset': 207,
#   'Score': 0.9783893823623657,
#   'Text': 'skin',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 49,
#   'BeginOffset': 209,
#   'EndOffset': 228,
#   'Score': 0.9614887833595276,
#   'Text': 'subcutaneous tissue',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 50,
#   'BeginOffset': 233,
#   'EndOffset': 239,
#   'Score': 0.9813277125358582,
#   'Text': 'muscle',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 3,
#   'BeginOffset': 246,
#   'EndOffset': 269,
#   'Score': 0.9048682451248169,
#   'Text': 'removal of foreign body',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 29,
#   'BeginOffset': 257,
#   'EndOffset': 269,
#   'Score': 0.7340391874313354,
#   'Text': 'foreign body',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.7541657090187073}]},
#  {'Id': 4,
#   'BeginOffset': 270,
#   'EndOffset': 280,
#   'Score': 0.9236363172531128,
#   'Text': 'ANESTHESIA',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 5,
#   'BeginOffset': 282,
#   'EndOffset': 285,
#   'Score': 0.31292399764060974,
#   'Text': 'LMA',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 30,
#   'BeginOffset': 312,
#   'EndOffset': 320,
#   'Score': 0.914691686630249,
#   'Text': 'pleasant',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'SIGN', 'Score': 0.8882427215576172}]},
#  {'Id': 20,
#   'BeginOffset': 321,
#   'EndOffset': 323,
#   'Score': 0.9998418092727661,
#   'Text': '60',
#   'Category': 'PROTECTED_HEALTH_INFORMATION',
#   'Type': 'AGE',
#   'Traits': []},
#  {'Id': 51,
#   'BeginOffset': 364,
#   'EndOffset': 371,
#   'Score': 0.5120874643325806,
#   'Text': 'sigmoid',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 6,
#   'BeginOffset': 364,
#   'EndOffset': 381,
#   'Score': 0.9676284193992615,
#   'Text': 'sigmoid colectomy',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 31,
#   'BeginOffset': 386,
#   'EndOffset': 406,
#   'Score': 0.9348375797271729,
#   'Text': 'diverticular abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.950272798538208}]},
#  {'Id': 32,
#   'BeginOffset': 427,
#   'EndOffset': 437,
#   'Score': 0.8686356544494629,
#   'Text': 'dehiscence',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8173336386680603}]},
#  {'Id': 7,
#   'BeginOffset': 443,
#   'EndOffset': 455,
#   'Score': 0.46262505650520325,
#   'Text': 'evisceration',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 33,
#   'BeginOffset': 497,
#   'EndOffset': 501,
#   'Score': 0.9542452692985535,
#   'Text': 'pain',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.5753875970840454}]},
#  {'Id': 54,
#   'BeginOffset': 519,
#   'EndOffset': 526,
#   'Score': 0.9990608096122742,
#   'Text': 'abdomen',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 8,
#   'BeginOffset': 528,
#   'EndOffset': 535,
#   'Score': 0.9861012101173401,
#   'Text': 'CT scan',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'TEST_NAME',
#   'Traits': [],
#   'Attributes': [{'Type': 'TEST_VALUE',
#     'Score': 0.5409986972808838,
#     'RelationshipScore': 1.0,
#     'Id': 9,
#     'BeginOffset': 549,
#     'EndOffset': 592,
#     'Text': 'presence of an abscess beneath the incision',
#     'Traits': []}]},
#  {'Id': 34,
#   'BeginOffset': 564,
#   'EndOffset': 571,
#   'Score': 0.9455034732818604,
#   'Text': 'abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.8486451506614685}]},
#  {'Id': 56,
#   'BeginOffset': 584,
#   'EndOffset': 592,
#   'Score': 0.40653714537620544,
#   'Text': 'incision',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 10,
#   'BeginOffset': 638,
#   'EndOffset': 659,
#   'Score': 0.2771005928516388,
#   'Text': 'above-named procedure',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 11,
#   'BeginOffset': 811,
#   'EndOffset': 818,
#   'Score': 0.9189378023147583,
#   'Text': 'surgery',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 35,
#   'BeginOffset': 862,
#   'EndOffset': 869,
#   'Score': 0.96346515417099,
#   'Text': 'abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.7921442985534668}]},
#  {'Id': 57,
#   'BeginOffset': 905,
#   'EndOffset': 911,
#   'Score': 0.9751610159873962,
#   'Text': 'fascia',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 59,
#   'BeginOffset': 939,
#   'EndOffset': 945,
#   'Score': 0.9920706152915955,
#   'Text': 'fascia',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 12,
#   'BeginOffset': 997,
#   'EndOffset': 1018,
#   'Score': 0.658248245716095,
#   'Text': 'excisionally debrided',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 13,
#   'BeginOffset': 1029,
#   'EndOffset': 1042,
#   'Score': 0.6999691724777222,
#   'Text': 'Bovie cautery',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 36,
#   'BeginOffset': 1096,
#   'EndOffset': 1101,
#   'Score': 0.668894350528717,
#   'Text': 'wound',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.7419555187225342}]},
#  {'Id': 21,
#   'BeginOffset': 1188,
#   'EndOffset': 1202,
#   'Score': 0.5146369338035583,
#   'Text': 'operating room',
#   'Category': 'PROTECTED_HEALTH_INFORMATION',
#   'Type': 'ADDRESS',
#   'Traits': []},
#  {'Id': 14,
#   'BeginOffset': 1216,
#   'EndOffset': 1251,
#   'Score': 0.3370138704776764,
#   'Text': 'induction of appropriate anesthesia',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 60,
#   'BeginOffset': 1257,
#   'EndOffset': 1264,
#   'Score': 0.9883460402488708,
#   'Text': 'abdomen',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 22,
#   'BeginOffset': 1282,
#   'EndOffset': 1290,
#   'Score': 0.9797016382217407,
#   'Text': 'Betadine',
#   'Category': 'MEDICATION',
#   'Type': 'BRAND_NAME',
#   'Traits': [],
#   'Attributes': [{'Type': 'FORM',
#     'Score': 0.9339338541030884,
#     'RelationshipScore': 0.9997135996818542,
#     'Id': 23,
#     'BeginOffset': 1291,
#     'EndOffset': 1299,
#     'Text': 'solution',
#     'Traits': []}]},
#  {'Id': 37,
#   'BeginOffset': 1337,
#   'EndOffset': 1342,
#   'Score': 0.29914772510528564,
#   'Text': 'wound',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': []},
#  {'Id': 38,
#   'BeginOffset': 1421,
#   'EndOffset': 1426,
#   'Score': 0.5273061394691467,
#   'Text': 'wound',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.6435200572013855}]},
#  {'Id': 39,
#   'BeginOffset': 1486,
#   'EndOffset': 1493,
#   'Score': 0.5879835486412048,
#   'Text': 'abscess',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.45991435647010803}]},
#  {'Id': 15,
#   'BeginOffset': 1629,
#   'EndOffset': 1636,
#   'Score': 0.39285358786582947,
#   'Text': 'excised',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 61,
#   'BeginOffset': 1692,
#   'EndOffset': 1707,
#   'Score': 0.4573522210121155,
#   'Text': 'necrotic fascia',
#   'Category': 'ANATOMY',
#   'Type': 'SYSTEM_ORGAN_SITE',
#   'Traits': []},
#  {'Id': 40,
#   'BeginOffset': 1713,
#   'EndOffset': 1718,
#   'Score': 0.8498033881187439,
#   'Text': 'wound',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.792850136756897}]},
#  {'Id': 16,
#   'BeginOffset': 1734,
#   'EndOffset': 1742,
#   'Score': 0.7435903549194336,
#   'Text': 'cultures',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'TEST_NAME',
#   'Traits': []},
#  {'Id': 41,
#   'BeginOffset': 1803,
#   'EndOffset': 1813,
#   'Score': 0.8167795538902283,
#   'Text': 'hemostasis',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'SIGN', 'Score': 0.7088011503219604}]},
#  {'Id': 42,
#   'BeginOffset': 1819,
#   'EndOffset': 1824,
#   'Score': 0.9190257787704468,
#   'Text': 'wound',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.7362188696861267}]},
#  {'Id': 17,
#   'BeginOffset': 1841,
#   'EndOffset': 1851,
#   'Score': 0.48244649171829224,
#   'Text': 'antibiotic',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'TREATMENT_NAME',
#   'Traits': []},
#  {'Id': 18,
#   'BeginOffset': 1868,
#   'EndOffset': 1888,
#   'Score': 0.29798462986946106,
#   'Text': 'dressing was applied',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 43,
#   'BeginOffset': 1903,
#   'EndOffset': 1908,
#   'Score': 0.5689261555671692,
#   'Text': 'wound',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'DIAGNOSIS', 'Score': 0.5514341592788696}]},
#  {'Id': 44,
#   'BeginOffset': 1954,
#   'EndOffset': 1982,
#   'Score': 0.3668334484100342,
#   'Text': 'tolerated the procedure well',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'SIGN', 'Score': 0.5777904391288757}]},
#  {'Id': 19,
#   'BeginOffset': 1984,
#   'EndOffset': 2004,
#   'Score': 0.5918566584587097,
#   'Text': 'Dressing was applied',
#   'Category': 'TEST_TREATMENT_PROCEDURE',
#   'Type': 'PROCEDURE_NAME',
#   'Traits': []},
#  {'Id': 45,
#   'BeginOffset': 2043,
#   'EndOffset': 2059,
#   'Score': 0.7319455146789551,
#   'Text': 'stable condition',
#   'Category': 'MEDICAL_CONDITION',
#   'Type': 'DX_NAME',
#   'Traits': [{'Name': 'SIGN', 'Score': 0.9023457765579224}]}]

# %%
c = []
for me in mes:
    c += [dic["Category"] for dic in me]
set(c)
# Out:
# {'ANATOMY',
#  'MEDICAL_CONDITION',
#  'MEDICATION',
#  'PROTECTED_HEALTH_INFORMATION',
#  'TEST_TREATMENT_PROCEDURE'}

# %%
c = []
for me in mes:
    c += [dic["Type"] for dic in me]
set(c)
# Out:
# {'ADDRESS',
#  'AGE',
#  'BRAND_NAME',
#  'DATE',
#  'DX_NAME',
#  'GENERIC_NAME',
#  'ID',
#  'NAME',
#  'PROCEDURE_NAME',
#  'PROFESSION',
#  'SYSTEM_ORGAN_SITE',
#  'TEST_NAME',
#  'TREATMENT_NAME'}
